# %%
import requests
import pandas as pd
import numpy as np
import requests
import bs4
import ssl
import certifi
import time

# %%
forbes = pd.read_excel('forbes_1000.xlsx')
for i in forbes.Domain:
    try:
        print('https://www.' + i)
    except:
        pass
# Out:
# https://www.walmart.com
# https://www.gm.com
# https://www.exxonmobil.com
# https://www.ford.com
# https://www.ge.com
# https://www.citigroup.com
# https://www.chevrontexaco.com
# https://www.ibm.com
# https://www.aig.com
# https://www.verizon.com
# https://www.altria.com
# https://www.conocophillips.com
# https://www.homedepot.com
# https://www.hp.com
# https://www.boeing.com
# https://www.fanniemae.com
# https://www.merck.com
# https://www.kroger.com
# https://www.cardinal.com
# https://www.mckesson.com
# https://www.statefarm.com
# https://www.att.com
# https://www.bankofamerica.com
# https://www.amerisourcebergen.net
# https://www.target.com
# https://www.jpmorganchase.com
# https://www.sbc.com
# https://www.berkshirehathaway.com
# https://www.aoltimewarner.com
# https://www.sears.com
# https://www.pg.com
# https://www.freddiemac.com
# https://www.costco.com
# https://www.jnj.com
# https://www.albertsons.com
# https://www.dell.com
# https://www.pfizer.com
# https://www.metlife.com
# https://www.bluelight.com
# https://www.morganstanley.com
# https://www.safeway.com
# https://www.jcpenney.net
# https://www.ups.com
# https://www.allstate.com
# https://www.walgreens.com
# https://www.wellsfargo.com
# https://www.microsoft.com
# https://www.ml.com
# https://www.utc.com
# https://www.conagra.com
# https://www.dow.com
# https://www.marathon.com
# https://www.delphi.com
# https://www.sprint.com
# https://www.valero.com
# https://www.lockheedmartin.com
# https://www.prudential.com
# https://www.intel.com
# https://www.motorola.com
# https://www.lowes.com
# https://www.disney.com
# https://www.pepsico.com
# https://www.unitedhealthgroup.com
# https://www.ipaper.com
# https://www.newyorklife.com
# https://www.viacom.com
# https://www.dupont.com
# https://www.cvs.com
# https://www.americanexpress.com
# https://www.wachovia.com
# https://www.admworld.com
# https://www.tyson.com
# https://www.sysco.com
# https://www.gp.com
# https://www.gs.com
# https://www.ingrammicro.com
# https://www.bellsouth.com
# https://www.honeywell.com
# https://www.bankone.com
# https://www.eds.com
# https://www.supervalu.com
# https://www.alcoa.com
# https://www.fedex.com
# https://www.massmutual.com
# https://www.cat.com
# https://www.johnsoncontrols.com
# https://www.cigna.com
# https://www.aetna.com
# https://www.tiaa-cref.org
# https://www.hcahealthcare.com
# https://www.bestbuy.com
# https://www.coca-cola.com
# https://www.autonation.com
# https://www.wamu.com
# https://www.cisco.com
# https://www.weyerhaeuser.com
# https://www.visteon.com
# https://www.bms.com
# https://www.northropgrumman.com
# https://www.abbott.com
# https://www.saralee.com
# https://www.fleming.com
# https://www.wellpoint.com
# https://www.amrcorp.com
# https://www.raytheon.com
# https://www.pharmacia.com
# https://www.loews.com
# https://www.cokecce.com
# https://www.lehman.com
# https://www.mmm.com
# https://www.nationwide.com
# https://www.publix.com
# https://www.northwesternmutual.com
# https://www.thehartford.com
# https://www.fleetboston.com
# https://www.xerox.com
# https://www.techdata.com
# https://www.duke-energy.com
# https://www.attws.com
# https://www.aep.com
# https://www.qwest.com
# https://www.fds.com
# https://www.usbank.com
# https://www.mcdonalds.com
# https://www.riteaid.com
# https://www.exeloncorp.com
# https://www.household.com
# https://www.wyeth.com
# https://www.libertymutual.com
# https://www.gapinc.com
# https://www.lear.com
# https://www.united.com
# https://www.cendant.com
# https://www.txucorp.com
# https://www.deere.com
# https://www.tenethealth.com
# https://www.gd.com
# https://www.gotoemerson.com
# https://www.goodyear.com
# https://www.pgecorp.com
# https://www.lucent.com
# https://www.anheuser-busch.com
# https://www.kimberly-clark.com
# https://www.maycompany.com
# https://www.delta.com
# https://www.anthem.com
# https://www.express-scripts.com
# https://www.advancepcs.com
# https://www.winn-dixie.com
# https://www.kodak.com
# https://www.circuitcity.com
# https://www.elpaso.com
# https://www.halliburton.com
# https://www.sunocoinc.com
# https://www.sun.com
# https://www.up.com
# https://www.comcast.com
# https://www.solectron.com
# https://www.firstenergycorp.com
# https://www.cinergy.com
# https://www.tjx.com
# https://www.hess.com
# https://www.edison.com
# https://www.reliantresources.com
# https://www.staples.com
# https://www.officedepot.com
# https://www.csc.com
# https://www.toysrus.com
# https://www.humana.com
# https://www.pacificare.com
# https://www.wm.com
# https://www.lilly.com
# https://www.whirlpoolcorp.com
# https://www.textron.com
# https://www.marriott.com
# https://www.manpower.com
# https://www.southernco.com
# https://www.mmc.com
# https://www.mbna.com
# https://www.xcelenergy.com
# https://www.aesc.com
# https://www.dana.com
# https://www.aflac.com
# https://www.dom.com
# https://www.health.net
# https://www.fluor.com
# https://www.schering-plough.com
# https://www.nike.com
# https://www.itw.com
# https://www.oracle.com
# https://www.capitalone.com
# https://www.unumprovident.com
# https://www.nwa.com
# https://www.heinz.com
# https://www.masco.com
# https://www.williams.com
# https://www.progressive.com
# https://www.colgate.com
# https://www.usaa.com
# https://www.pbg.com
# https://www.deanfoods.com
# https://www.limitedbrands.com
# https://www.chubb.com
# https://www.kohls.com
# https://www.bnsf.com
# https://www.avnet.com
# https://www.stpaul.com
# https://www.jhancock.com
# https://www.countrywide.com
# https://www.principal.com
# https://www.pseg.com
# https://www.aon.com
# https://www.aramark.com
# https://www.sanmina.com
# https://www.nationalcity.com
# https://www.nextel.com
# https://www.conedison.com
# https://www.gillette.com
# https://www.clearchannel.com
# https://www.continental.com
# https://www.plainsallamerican.com
# https://www.baxter.com
# https://www.ti.com
# https://www.entergy.com
# https://www.kelloggs.com
# https://www.fplgroup.com
# https://www.genpt.com
# https://www.progress-energy.com
# https://www.dillards.com
# https://www.smurfit-stone.com
# https://www.csx.com
# https://www.glic.com
# https://www.ppg.com
# https://www.alltel.com
# https://www.generalmills.com
# https://www.centerpointenergy.com
# https://www.chsco-ops.com
# https://www.americanstandard.com
# https://www.ashland.com
# https://www.yum.com
# https://www.centex.com
# https://www.firstdata.com
# https://www.farmland.com
# https://www.unitedauto.com
# https://www.arrow.com
# https://www.calpine.com
# https://www.omnicomgroup.com
# https://www.suntrust.com
# https://www.meadwestvaco.com
# https://www.pulte.com
# https://www.newellco.com
# https://www.oxy.com
# https://www.sonicautomotive.com
# https://www.bc.com
# https://www.smithfieldfoods.com
# https://www.lennar.com
# https://www.paccar.com
# https://www.eaton.com
# https://www.mirant.com
# https://www.safeco.com
# https://www.adp.com
# https://www.usairways.com
# https://www.tesoropetroleum.com
# https://www.uss.com
# https://www.bearstearns.com
# https://www.arvinmeritor.com
# https://www.caremarkrx.com
# https://www.crowncork.com
# https://www.premcor.com
# https://www.dteenergy.com
# https://www.drhorton.com
# https://www.cmsenergy.com
# https://www.nisource.com
# https://www.navistar.com
# https://www.gannett.com
# https://www.medtronic.com
# https://www.pnc.com
# https://www.53.com
# https://www.nscorp.com
# https://www.avon.com
# https://www.rjrholdings.com
# https://www.interpublic.com
# https://www.parker.com
# https://www.conseco.com
# https://www.keybank.com
# https://www.campbellsoup.com
# https://www.bbandt.com
# https://www.saic.com
# https://www.dollargeneral.com
# https://www.keyspanenergy.com
# https://www.sempra.com
# https://www.agilent.com
# https://www.nordstrom.com
# https://www.saksincorporated.com
# https://www.bjswholesale.com
# https://www.cummins.com
# https://www.landolakesinc.com
# https://www.o-i.com
# https://www.bankofny.com
# https://www.apple.com
# https://www.rohmhaas.com
# https://www.thrivent.com
# https://www.unisys.com
# https://www.ncr.com
# https://www.amgen.com
# https://www.southwest.com
# https://www.alliedwaste.com
# https://www.emc.com
# https://www.pplweb.com
# https://www.federal-mogul.com
# https://www.airproducts.com
# https://www.tribune.com
# https://www.fortunebrands.com
# https://www.autozone.com
# https://www.eastman.com
# https://www.unocal.com
# https://www.cit.com
# https://www.bn.com
# https://www.usainteractive.com
# https://www.bakerhughes.com
# https://www.sherwin.com
# https://www.vfc.com
# https://www.amfam.com
# https://www.praxair.com
# https://www.wellchoice.com
# https://www.fnf.com
# https://www.appliedmaterials.com
# https://www.spx.com
# https://www.cox.com
# https://www.nu.com
# https://www.omgi.com
# https://www.kbhome.com
# https://www.itt.com
# https://www.oxhp.com
# https://www.avaya.com
# https://www.dynegy.com
# https://www.mattel.com
# https://www.owenscorning.com
# https://www.ikon.com
# https://www.statestreet.com
# https://www.dishnetwork.com
# https://www.nucor.com
# https://www.mcgraw-hill.com
# https://www.maytag.com
# https://www.ryder.com
# https://www.officemax.com
# https://www.cnf.com
# https://www.rrdonnelley.com
# https://www.elcompanies.com
# https://www.mellon.com
# https://www.firstam.com
# https://www.constellationenergy.com
# https://www.templeinland.com
# https://www.parkplace.com
# https://www.grainger.com
# https://www.lfg.com
# https://www.danaher.com
# https://www.radioshackcorporation.com
# https://www.jacobs.com
# https://www.asburyauto.com
# https://www.mohawkind.com
# https://www.chartercom.com
# https://www.footlocker-inc.com
# https://www.schwab.com
# https://www.autoliv.com
# https://www.pfgc.com
# https://www.longs.com
# https://www.pitneybowes.com
# https://www.devonenergy.com
# https://www.bdk.com
# https://www.dole.com
# https://www.darden.com
# https://www.lexmark.com
# https://www.mutualofomaha.com
# https://www.jny.com
# https://www.aksteel.com
# https://www.pepcoholdings.com
# https://www.kellyservices.com
# https://www.healthsouth.com
# https://www.leggett.com
# https://www.cdw.com
# https://www.dovercorporation.com
# https://www.group1auto.com
# https://www.averydennison.com
# https://www.goodrich.com
# https://www.harrahs.com
# https://www.gateway.com
# https://www.familydollar.com
# https://www.levistrauss.com
# https://www.hersheys.com
# https://www.questdiagnostics.com
# https://www.harley-davidson.com
# https://www.providian.com
# https://www.clorox.com
# https://www.pittston.com
# https://www.bd.com
# https://www.mgmmirage.com
# https://www.L-3com.com
# https://www.engyeast.com
# https://www.cablevision.com
# https://www.graybar.com
# https://www.murphyoilcorp.com
# https://www.ntl.com
# https://www.emcorgroup.com
# https://www.owens-minor.com
# https://www.pathmark.com
# https://www.amazon.com
# https://www.hormel.com
# https://www.rockwell.com
# https://www.nashfinch.com
# https://www.collinsaikman.com
# https://www.starwood.com
# https://www.biglots.com
# https://www.anadarko.com
# https://www.ball.com
# https://www.hilton.com
# https://www.york.com
# https://www.ameren.com
# https://www.pacificlife.com
# https://www.regions.com
# https://www.maxtor.com
# https://www.coors.com
# https://www.engelhard.com
# https://www.amfnl.com
# https://www.gdw.com
# https://www.kerr-mcgee.com
# https://www.wisenergy.com
# https://www.phelpsdodge.com
# https://www.lizclaiborne.com
# https://www.brunswickcorp.com
# https://www.unitedstationers.com
# https://www.kiewit.com
# https://www.comerica.com
# https://www.hostmarriott.com
# https://www.wgint.com
# https://www.roundys.com
# https://www.svm.com
# https://www.epplp.com
# https://www.cvty.com
# https://www.bethsteel.com
# https://www.jabil.com
# https://www.triadhospitals.com
# https://www.irin.com/ibc
# https://www.rossstores.com
# https://www.auto-owners.com
# https://www.bordersgroupinc.com
# https://www.spartanstores.com
# https://www.equityoffice.com
# https://www.encompserv.com
# https://www.aam.com
# https://www.jpfinancial.com
# https://www.usg.com
# https://www.tenneco-automotive.com
# https://www.erieinsurance.com
# https://www.corning.com
# https://www.allmerica.com
# https://www.ecolab.com
# https://www.airborne.com
# https://www.coopertire.com
# https://www.southtrust.com
# https://www.wescodist.com
# https://www.hrblock.com
# https://www.kindredhealthcare.com
# https://www.chrobinson.com
# https://www.starbucks.com
# https://www.advanceautoparts.com
# https://www.lyondell.com
# https://www.uhsinc.com
# https://www.shopko.com
# https://www.pepsiamericas.com
# https://www.guidant.com
# https://www.fisherscientific.com
# https://www.salliemae.com
# https://www.yellowcorp.com
# https://www.sealedair.com
# https://www.roadwaycorp.com
# https://www.aquila.com
# https://www.armstrong.com
# https://www.shawgrp.com
# https://www.smith.com
# https://www.level3.com
# https://www.nvrinc.com
# https://www.reebok.com
# https://www.oge.com
# https://www.steelcase.com
# https://www.nytco.com
# https://www.hughessupply.com
# https://www.acs-inc.com
# https://www.qualcomm.com
# https://www.acehardware.com
# https://www.lennoxinternational.com
# https://www.amsouth.com
# https://www.strykercorp.com
# https://www.sierrapacific.com
# https://www.teldta.com
# https://www.alleghenyenergy.com
# https://www.br-inc.com
# https://www.ca.com
# https://www.scana.com
# https://www.neimanmarcus.com
# https://www.bedbathandbeyond.com
# https://www.agcocorp.com
# https://www.bostonscientific.com
# https://www.uwgrocers.com
# https://www.hcr-manorcare.com
# https://www.insight.com
# https://www.brinker.com
# https://www.pactiv.com
# https://www.paylessshoesource.com
# https://www.ryland.com
# https://www.michaels.com
# https://www.multifoods.com
# https://www.cinfin.com
# https://www.kri.com
# https://www.charterone.com
# https://www.henryschein.com
# https://www.unitedrentals.com
# https://www.cbrands.com
# https://www.hasbro.com
# https://www.sonoco.com
# https://www.solutia.com
# https://www.terex.com
# https://www.vulcanmaterials.com
# https://www.ntrs.com
# https://www.oldrepublic.com
# https://www.towerautomotive.com
# https://www.wrigley.com
# https://www.torchmarkcorp.com
# https://www.bwauto.com
# https://www.wendys.com
# https://www.nstaronline.com
# https://www.peabodyenergy.com
# https://www.tecoenergy.com
# https://www.northwestern.com
# https://www.amd.com
# https://www.petsmart.com
# https://www.wholefoods.com
# https://www.unionplanters.com
# https://www.wpsr.com
# https://www.czn.com
# https://www.staterbros.com
# https://www.alberto.com
# https://www.micorp.com
# https://www.ruddickcorp.com
# https://www.beazer.com
# https://www.pinnaclewest.com
# https://www.omnicare.com
# https://www.ghv.com
# https://www.alliant-energy.com
# https://www.coat.com
# https://www.stanleyworks.com
# https://www.sungard.com
# https://www.micron.com
# https://www.landam.com
# https://www.washpostco.com
# https://www.bowater.com
# https://www.pentair.com
# https://www.firsttennessee.com
# https://www.popularinc.com
# https://www.polyone.com
# https://www.wrbc.com
# https://www.apachecorp.com
# https://www.precast.com
# https://www.khov.com
# https://www.timken.com
# https://www.nacco.com
# https://www.cromptoncorp.com
# https://www.pilgrimspride.com
# https://www.anixter.com
# https://www.frk.com
# https://www.labcorp.com
# https://www.beverlynet.com
# https://www.universalcorp.com
# https://www.thepantry.com
# https://www.sovereignbank.com
# https://www.rockwellcollins.com
# https://www.westerngas.com
# https://www.duraauto.com
# https://www.dkwd.com
# https://www.phoenixwm.com
# https://www.commercialmetals.com
# https://www.usfreightways.com
# https://www.exideworld.com
# https://www.urscorp.com
# https://www.charmingshoppes.com
# https://www.valuecity.com
# https://www.furniturebrands.com
# https://www.pse.com
# https://www.lithia.com
# https://www.bemis.com
# https://www.rd.com
# https://www.penntraffic.com
# https://www.bearingpoint.com
# https://www.republicservices.com
# https://www.agedwards.com
# https://www.polo.com
# https://www.chiquita.com
# https://www.outback.com
# https://www.williams-sonomainc.com
# https://www.americangreetings.com
# https://www.mandtbank.com
# https://www.mandalayresortgroup.com
# https://www.dollartree.com
# https://www.tollbrothers.com
# https://www.mamsi.com
# https://www.pios.com
# https://www.mccormick.com
# https://www.richmondamerican.com
# https://www.imcglobal.com
# https://www.unitrin.com
# https://www.expeditors.com
# https://www.synovus.com
# https://www.convergys.com
# https://www.cunamutual.com
# https://www.newmont.com
# https://www.fleetwood.com
# https://www.fiserv.com
# https://www.sci-corp.com
# https://www.cintas.com
# https://www.lpcorp.com
# https://www.hma-corp.com
# https://www.belk.com
# https://www.flowserve.com
# https://www.jbhunt.com
# https://www.anico.com
# https://www.broadwing.com
# https://www.alaskaair.com
# https://www.centurytel.com
# https://www.huntington.com
# https://www.ugicorp.com
# https://www.kellwood.com
# https://www.chs.net
# https://www.cellstar.com
# https://www.abm.com
# https://www.zalecorp.com
# https://www.shopsimon.com
# https://www.lnt.com
# https://www.truserv.com
# https://www.concordefs.com
# https://www.pepboys.com
# https://www.oneok.com
# https://www.lazboy.com
# https://www.westerndigital.com
# https://www.hillenbrand.com
# https://www.spherion.com
# https://www.regalcinemas.com
# https://www.valspar.com
# https://www.snapon.com
# https://www.bellmicro.com
# https://www.swifttrans.com
# https://www.ryersontull.com
# https://www.mony.com
# https://www.thermo.com
# https://www.teleflex.com
# https://www.fmctechnologies.com
# https://www.libertymedia.com
# https://www.uhaul.com
# https://www.cbrlgroup.com
# https://www.beckmancoulter.com
# https://www.caseys.com
# https://www.sabre.com
# https://www.americawest.com
# https://www.equityapartments.com
# https://www.storagetek.com
# https://www.mdu.com
# https://www.harsco.com
# https://www.paychex.com
# https://www.rentacenter.com
# https://www.weismarkets.com
# https://www.ch2m.com
# https://www.quintiles.com
# https://www.hayes-lemmerz.com
# https://www.silgan.com
# https://www.rpminc.com
# https://www.lubrizol.com
# https://www.herc.com
# https://www.acuitybrands.com
# https://www.carlisle.com
# https://www.sunh.com
# https://www.jackinthebox.com
# https://www.ingles-markets.com
# https://www.brown-forman.com
# https://www.peoplesoft.com
# https://www.walterind.com
# https://www.diebold.com
# https://www.igtonline.com
# https://www.protective.com
# https://www.scholastic.com
# https://www.fcx.com
# https://www.nvidia.com
# https://www.alleghenytechnologies.com
# https://www.rhi.com
# https://www.etrade.com
# https://www.nicor.com
# https://www.nortek-inc.com
# https://www.fmglobal.com
# https://www.standardpacifichomes.com
# https://www.harris.com
# https://www.cornproducts.com
# https://www.wyndham.com
# https://www.tatravelcenters.com
# https://www.eaglegl.com
# https://www.bjservices.com
# https://www.goldkist.com
# https://www.marinerhealth.com
# https://www.greatplainsenergy.com
# https://www.davita.com
# https://www.fmc.com
# https://www.brownshoe.com
# https://www.grace.com
# https://www.zionsbancorporation.com
# https://www.njresources.com
# https://www.seaboardcorp.com
# https://www.compassweb.com
# https://www.harman.com
# https://www.sentry.com
# https://www.vishay.com
# https://www.lsilogic.com
# https://www.bausch.com
# https://www.pssd.com/wmi
# https://www.frontieroil.com
# https://www.westpointstevens.com
# https://www.iff.com
# https://www.vectren.com
# https://www.atk.com
# https://www.wr.com
# https://www.metaldyne.com
# https://www.mercuryinsurance.com
# https://www.marsh.net
# https://www.stewart.com
# https://www.markelcorp.com
# https://www.stancorpfinancial.com
# https://www.greenpoint.com
# https://www.magellanhealth.com
# https://www.graniteconstruction.com
# https://www.scotts.com
# https://www.quantaservices.com
# https://www.hewitt.com
# https://www.rsac.com
# https://www.worthingtonindustries.com
# https://www.oshkoshtruck.com
# https://www.energizer.com
# https://www.packagingcorp.com
# https://www.ferro.com
# https://www.mail-well.com
# https://www.compuware.com
# https://www.uniteddefense.com
# https://www.ea.com
# https://www.molex.com
# https://www.analog.com
# https://www.tiffany.com
# https://www.ocas.com
# https://www.applera.com
# https://www.minnesotamutual.com
# https://www.honi.com
# https://www.sequa.com
# https://www.safeguard.com
# https://www.joann.com
# https://www.scientificatlanta.com
# https://www.dstsystems.com
# https://www.mgm.com
# https://www.hei.com
# https://www.greif.com
# https://www.flowersfoods.com
# https://www.usoncology.com
# https://www.viad.com
# https://www.ufpi.com
# https://www.amkor.com
# https://www.ustinc.com
# https://www.kla-tencor.com
# https://www.comdisco.com
# https://www.allergan.com
# https://www.airgas.com
# https://www.siebel.com
# https://www.allete.com
# https://www.bench.com
# https://www.masseyenergyco.com
# https://www.perkinelmer.com
# https://www.scripps.com
# https://www.pacer-international.com
# https://www.frx.com
# https://www.abercrombie.com
# https://www.sjm.com
# https://www.hubbell.com
# https://www.primedia.com
# https://www.wglholdings.com
# https://www.kennametal.com
# https://www.leggmason.com
# https://www.mgic.com
# https://www.titan.com
# https://www.aimco.com
# https://www.mmoh.com
# https://www.whiterose.com
# https://www.dj.com
# https://www.cabot-corp.com
# https://www.millenniumchem.com
# https://www.systemax.com
# https://www.warnaco.com
# https://www.pier1.com
# https://www.cobaltcorporation.com
# https://www.wallace.com
# https://www.coopercameron.com
# https://www.archcoal.com
# https://www.idt.net
# https://www.briggsandstratton.com
# https://www.natoil.com
# https://www.ncfcorp.com
# https://www.polarisindustries.com
# https://www.craneco.com
# https://www.rjf.com
# https://www.greatlakeschem.com
# https://www.dentsply.com
# https://www.banknorth.com
# https://www.cskauto.com
# https://www.landstar.com
# https://www.veritas.com
# https://www.alpinegroup.com
# https://www.martinmarietta.com
# https://www.national.com
# https://www.volt.com
# https://www.hollywoodvideo.com
# https://www.trin.net
# https://www.pecorp.com
# https://www.uici.net
# https://www.3com.com
# https://www.petco.com
# https://www.ielectric.com
# https://www.sierrahealth.com
# https://www.manitowoc.com
# https://www.aosmith.com
# https://www.hermanmiller.com
# https://www.natfuel.com
# https://www.ae.com
# https://www.regiscorp.com
# https://www.generalcable.com
# https://www.appliedindustrial.com
# https://www.potlatchcorp.com
# https://www.amica.com
# https://www.nobleenergy.com
# https://www.rocktenn.com
# https://www.vno.com
# https://www.amerus.com
# https://www.imshealth.com
# https://www.belo.com
# https://www.sportsauthority.com
# https://www.usec.com
# https://www.arkbest.com
# https://www.federatedinsurance.com
# https://www.pattersondental.com
# https://www.fairchildsemi.com
# https://www.steinmart.com
# https://www.pvh.com
# https://www.toro.com
# https://www.contactpsc.com
# https://www.brightpoint.com
# https://www.ckr.com
# https://www.kofc.org
# https://www.metriscompanies.com
# https://www.anntaylor.com
# https://www.astoriafederal.com
# https://www.zimmer.com
# https://www.championhomes.net
# https://www.banta.com
# https://www.wfscorp.com
# https://www.intuit.com
# https://www.earthlink.net
# https://www.cytec.com
# https://www.dreyersinc.com
# https://www.tnb.com
# https://www.txi.com
# https://www.tecumseh.com
# https://www.amctheatres.com
# https://www.werner.com
# https://www.sgi.com
# https://www.hibernia.com
# https://www.handleman.com
# https://www.hubgroup.com
# https://www.varco.com
# https://www.dialcorp.com
# https://www.perotsystems.com
# https://www.genzyme.com
# https://www.delmonte.com
# https://www.swgas.com
# https://www.symbol.com
# https://www.ironmountain.com
# https://www.felcor.com
# https://www.tellabs.com
# https://www.ebworld.com
# https://www.northforkbank.com
# https://www.unova.com
# https://www.oreillyauto.com
# https://www.foamex.com
# https://www.olin.com
# https://www.apcc.com
# https://www.imperialsugar.com
# https://www.menswearhouse.com
# https://www.cadence.com
# https://www.pall.com
# https://www.southernunionco.com
# https://www.bmc.com
# https://www.blythinc.com
# https://www.riverwood.com
# https://www.deluxe.com
# https://www.sweetheart.com
# https://www.twec.com
# https://www.dadebehring.com
# https://www.giant.com
# https://www.ralcorp.com
# https://www.ata.com
# https://www.chiron.com
# https://www.dnb.com
# https://www.dominos.com
# https://www.duanereade.com
# https://www.gatx.com
# https://www.crbard.com
# https://www.prideinternational.com
# https://www.agway.com
# https://www.xo.com
# https://www.dimon.com
# https://www.commerceinsurance.com
# https://www.hbfuller.com
# https://www.harleysvillegroup.com
# https://www.apria.com
# https://www.daisytek.com
# https://www.sigmaaldrich.com
# https://www.cokeconsolidated.com
# https://www.thorindustries.com
# https://www.mcleodusa.com
# https://www.bostonproperties.com
# https://www.westcorpinc.com
# https://www.mbia.com
# https://www.bordenchem.com
# https://www.ggc.com
# https://www.trump.com
# https://www.boydgaming.com
# https://www.williamscommunications.com
# https://www.watsonpharm.com
# https://www.monaco-online.com
# https://www.teradyne.com
# https://www.unioncentral.com
# https://www.therousecompany.com
# https://www.verisign.com
# https://www.wcicommunities.com
# https://www.ebay.com
# https://www.mt.com
# https://www.providentbank.com
# https://www.tractorsupplyco.com
# https://www.cdicorp.com
# https://www.questarcorp.com
# https://www.priorityhealthcare.com
# https://www.greyglobalgroup.com
# https://www.clayton.net
# https://www.ivax.com
# https://www.atmel.com
# https://www.goodysonline.com
# https://www.ceridian.com
# https://www.griffoncorp.com
# https://www.biomet.com
# https://www.pcconnection.com
# https://www.timberland.com
# https://www.americredit.com
# https://www.sealy.com
# https://www.barrlabs.com
# https://www.ssss.com
# https://www.selective.com
# https://www.wwireless.com
# https://www.nrucfc.org
# https://www.dplinc.com
# https://www.oneamerica.biz
# https://www.watsco.com
# https://www.kingpharm.com
# https://www.unfi.com
# https://www.kimball.com
# https://www.pnm.com
# https://www.michaelfoods.com
# https://www.dqe.com
# https://www.adobe.com
# https://www.russellcorp.com
# https://www.opc.com
# https://www.oceanenergy.com
# https://www.gemstartvguide.com
# https://www.bmhc.com
# https://www.alexanderbaldwin.com
# https://www.amerigrp.com
# https://www.mpsgroup.com
# https://www.tcfbank.com
# https://www.radiangroupinc.com
# https://www.joyglobal.com.
# https://www.biogen.com
# https://www.janus.com
# https://www.gentek-global.com
# https://www.archstonecommunities.com
# https://www.plumcreek.com
# https://www.rayonier.com
# https://www.gencorp.com
# https://www.novell.com
# https://www.dtag.com
# https://www.acterna.com

# %%
def clean_rules(file):
    rules = pd.read_excel(file).T
    rules = rules.rename(columns=rules.iloc[0]).drop(rules.index[0])
    rules = rules[rules.index.str.contains('Result')]
    rules.replace('Not Evaluated', 'No', inplace = True)
    rules.replace('Passed', 'Yes', inplace = True)
    rules.index = rules.index.str.replace(';Result', '')
    return rules

# %%
def clean_data(data):
    final = clean_rules(data)
    final.replace('No', 0, inplace = True)
    final.replace('Yes', 1, inplace = True)
    final = final.T
    conditions = [(final['Google Universal Exists'] == 1) | (final['GA4 Exists'] == 1), (final['Google Universal Exists'] == 0) & (final['GA4 Exists'] == 0)]
    values = [1, 0]
    final['Google Analytics Exists'] = np.select(conditions, values)
    final['Adobe and Google Analytics'] = final['Adobe Ananlytics Exists'] + final['Google Analytics Exists']
    final['Adobe and Google Analytics'].replace(1, 0, inplace = True)
    final['Adobe and Google Analytics'].replace(2, 1, inplace = True)
    final['Adobe and Tealium TMS'] = final['Adobe Ananlytics Exists'] + final['Tealium TMS Exists']
    final['Adobe and GTM'] = final['Adobe Ananlytics Exists'] + final['GTM exists']
    final['Adobe and Ensighten'] = final['Adobe Ananlytics Exists'] + final['Ensighten Exists']
    final['Adobe and Adobe DTM'] = final['Adobe Ananlytics Exists'] + final['Adobe DTM Exists']
    final['Adobe and Adobe Target'] = final['Adobe Ananlytics Exists'] + final['Adobe Target Exists']
    final['Google and Tealium TMS'] = final['Google Analytics Exists'] + final['Tealium TMS Exists']
    final['Google and GTM'] = final['Google Analytics Exists'] + final['GTM exists']
    final['Google and Ensighten'] = final['Google Analytics Exists'] + final['Ensighten Exists']
    final['Google and Adobe DTM'] = final['Google Analytics Exists'] + final['Adobe DTM Exists']
    final['Google and Google Optimize'] = final['Google Analytics Exists'] + final['Google Optimize Exists']
    final[['Adobe and Tealium TMS', 'Adobe and GTM', 'Adobe and Ensighten', 'Adobe and Adobe DTM', 'Google and Tealium TMS', 'Google and GTM', 'Google and Ensighten', 'Google and Adobe DTM', 'Adobe and Adobe Target', 'Google and Google Optimize']] = final[['Adobe and Tealium TMS', 'Adobe and GTM', 'Adobe and Ensighten', 'Adobe and Adobe DTM', 'Google and Tealium TMS', 'Google and GTM', 'Google and Ensighten', 'Google and Adobe DTM', 'Adobe and Adobe Target', 'Google and Google Optimize']].replace(1, 0)
    final[['Adobe and Tealium TMS', 'Adobe and GTM', 'Adobe and Ensighten', 'Adobe and Adobe DTM', 'Google and Tealium TMS', 'Google and GTM', 'Google and Ensighten', 'Google and Adobe DTM', 'Adobe and Adobe Target', 'Google and Google Optimize']] = final[['Adobe and Tealium TMS', 'Adobe and GTM', 'Adobe and Ensighten', 'Adobe and Adobe DTM', 'Google and Tealium TMS', 'Google and GTM', 'Google and Ensighten', 'Google and Adobe DTM', 'Adobe and Adobe Target', 'Google and Google Optimize']].replace(2, 1)
    final['GA + Google Optimize + GTM'] = final['Google Analytics Exists'] + final['Google Optimize Exists'] + final['GTM exists']
    final['AA + Adobe Target + Adobe DTM'] = final['Adobe Ananlytics Exists'] + final['Adobe Target Exists'] + final['Adobe DTM Exists']
    final[['GA + Google Optimize + GTM', 'AA + Adobe Target + Adobe DTM']] = final[['GA + Google Optimize + GTM', 'AA + Adobe Target + Adobe DTM']].replace(1, 0)
    final[['GA + Google Optimize + GTM', 'AA + Adobe Target + Adobe DTM']] = final[['GA + Google Optimize + GTM', 'AA + Adobe Target + Adobe DTM']].replace(2, 0)
    final[['GA + Google Optimize + GTM', 'AA + Adobe Target + Adobe DTM']] = final[['GA + Google Optimize + GTM', 'AA + Adobe Target + Adobe DTM']].replace(3, 1)

    return final

# %%
final = clean_data('SDRAuditFinalAttempt3_Rules_2736279_85d03acfcc4420718348814caa619268.xlsx')

# %%
top_50 = final.iloc[:50]
next_200 = final.iloc[50:251]
next_249 = final.iloc[251:500]
next_499 = final.iloc[500:1000]

# %%
final
# Out:
#                                        GTM exists  Adobe Ananlytics Exists  \
# https://3myms.eaglegl.com/default.asp           0                        0
# https://agt.fandom.com/wiki/CZN                 1                        0
# https://alberto-pants-usa.com/                  0                        0
# https://alexanderbaldwin.com/                   0                        0
# https://allengelhard.com/                       0                        0
# ...                                           ...                      ...
# https://www.yum.com/                            0                        0
# https://www.zalecorp.com                        0                        1
# https://www.zimmer.com                          0                        1
# https://wwwint.progress-energy.com/             0                        0
# https://yrc.com/                                1                        0
#
#                                        Google Universal Exists  \
# https://3myms.eaglegl.com/default.asp                        0
# https://agt.fandom.com/wiki/CZN                              1
# https://alberto-pants-usa.com/                               1
# https://alexanderbaldwin.com/                                1
# https://allengelhard.com/                                    1
# ...                                                        ...
# https://www.yum.com/                                         1
# https://www.zalecorp.com                                     1
# https://www.zimmer.com                                       1
# https://wwwint.progress-energy.com/                          0
# https://yrc.com/                                             1
#
#                                        Adobe Launch Exists  Adobe DTM Exists  \
# https://3myms.eaglegl.com/default.asp                    0                 0
# https://agt.fandom.com/wiki/CZN                          0                 0
# https://alberto-pants-usa.com/                           0                 0
# https://alexanderbaldwin.com/                            0                 0
# https://allengelhard.com/                                0                 0
# ...                                                    ...               ...
# https://www.yum.com/                                     0                 0
# https://www.zalecorp.com                                 0                 0
# https://www.zimmer.com                                   1                 0
# https://wwwint.progress-energy.com/                      0                 0
# https://yrc.com/                                         0                 0
#
#                                        Tealium TMS Exists  Ensighten Exists  \
# https://3myms.eaglegl.com/default.asp                   0                 0
# https://agt.fandom.com/wiki/CZN                         0                 0
# https://alberto-pants-usa.com/                          0                 0
# https://alexanderbaldwin.com/                           0                 0
# https://allengelhard.com/                               0                 0
# ...                                                   ...               ...
# https://www.yum.com/                                    0                 0
# https://www.zalecorp.com                                0                 1
# https://www.zimmer.com                                  0                 0
# https://wwwint.progress-energy.com/                     0                 0
# https://yrc.com/                                        0                 0
#
#                                        GA4 Exists  Mixpanel Exists  \
# https://3myms.eaglegl.com/default.asp           0                0
# https://agt.fandom.com/wiki/CZN                 1                0
# https://alberto-pants-usa.com/                  0                0
# https://alexanderbaldwin.com/                   0                0
# https://allengelhard.com/                       0                0
# ...                                           ...              ...
# https://www.yum.com/                            0                0
# https://www.zalecorp.com                        0                0
# https://www.zimmer.com                          0                0
# https://wwwint.progress-energy.com/             0                0
# https://yrc.com/                                0                0
#
#                                        Heap Exists  ...  Adobe and Ensighten  \
# https://3myms.eaglegl.com/default.asp            0  ...                    0
# https://agt.fandom.com/wiki/CZN                  0  ...                    0
# https://alberto-pants-usa.com/                   0  ...                    0
# https://alexanderbaldwin.com/                    0  ...                    0
# https://allengelhard.com/                        0  ...                    0
# ...                                            ...  ...                  ...
# https://www.yum.com/                             0  ...                    0
# https://www.zalecorp.com                         0  ...                    1
# https://www.zimmer.com                           0  ...                    0
# https://wwwint.progress-energy.com/              0  ...                    0
# https://yrc.com/                                 0  ...                    0
#
#                                        Adobe and Adobe DTM  \
# https://3myms.eaglegl.com/default.asp                    0
# https://agt.fandom.com/wiki/CZN                          0
# https://alberto-pants-usa.com/                           0
# https://alexanderbaldwin.com/                            0
# https://allengelhard.com/                                0
# ...                                                    ...
# https://www.yum.com/                                     0
# https://www.zalecorp.com                                 0
# https://www.zimmer.com                                   0
# https://wwwint.progress-energy.com/                      0
# https://yrc.com/                                         0
#
#                                        Adobe and Adobe Target  \
# https://3myms.eaglegl.com/default.asp                       0
# https://agt.fandom.com/wiki/CZN                             0
# https://alberto-pants-usa.com/                              0
# https://alexanderbaldwin.com/                               0
# https://allengelhard.com/                                   0
# ...                                                       ...
# https://www.yum.com/                                        0
# https://www.zalecorp.com                                    0
# https://www.zimmer.com                                      1
# https://wwwint.progress-energy.com/                         0
# https://yrc.com/                                            0
#
#                                        Google and Tealium TMS  Google and GTM  \
# https://3myms.eaglegl.com/default.asp                       0               0
# https://agt.fandom.com/wiki/CZN                             0               1
# https://alberto-pants-usa.com/                              0               0
# https://alexanderbaldwin.com/                               0               0
# https://allengelhard.com/                                   0               0
# ...                                                       ...             ...
# https://www.yum.com/                                        0               0
# https://www.zalecorp.com                                    0               0
# https://www.zimmer.com                                      0               0
# https://wwwint.progress-energy.com/                         0               0
# https://yrc.com/                                            0               1
#
#                                        Google and Ensighten  \
# https://3myms.eaglegl.com/default.asp                     0
# https://agt.fandom.com/wiki/CZN                           0
# https://alberto-pants-usa.com/                            0
# https://alexanderbaldwin.com/                             0
# https://allengelhard.com/                                 0
# ...                                                     ...
# https://www.yum.com/                                      0
# https://www.zalecorp.com                                  1
# https://www.zimmer.com                                    0
# https://wwwint.progress-energy.com/                       0
# https://yrc.com/                                          0
#
#                                        Google and Adobe DTM  \
# https://3myms.eaglegl.com/default.asp                     0
# https://agt.fandom.com/wiki/CZN                           0
# https://alberto-pants-usa.com/                            0
# https://alexanderbaldwin.com/                             0
# https://allengelhard.com/                                 0
# ...                                                     ...
# https://www.yum.com/                                      0
# https://www.zalecorp.com                                  0
# https://www.zimmer.com                                    0
# https://wwwint.progress-energy.com/                       0
# https://yrc.com/                                          0
#
#                                        Google and Google Optimize  \
# https://3myms.eaglegl.com/default.asp                           0
# https://agt.fandom.com/wiki/CZN                                 0
# https://alberto-pants-usa.com/                                  0
# https://alexanderbaldwin.com/                                   0
# https://allengelhard.com/                                       0
# ...                                                           ...
# https://www.yum.com/                                            0
# https://www.zalecorp.com                                        0
# https://www.zimmer.com                                          0
# https://wwwint.progress-energy.com/                             0
# https://yrc.com/                                                0
#
#                                        GA + Google Optimize + GTM  \
# https://3myms.eaglegl.com/default.asp                           0
# https://agt.fandom.com/wiki/CZN                                 0
# https://alberto-pants-usa.com/                                  0
# https://alexanderbaldwin.com/                                   0
# https://allengelhard.com/                                       0
# ...                                                           ...
# https://www.yum.com/                                            0
# https://www.zalecorp.com                                        0
# https://www.zimmer.com                                          0
# https://wwwint.progress-energy.com/                             0
# https://yrc.com/                                                0
#
#                                        AA + Adobe Target + Adobe DTM
# https://3myms.eaglegl.com/default.asp                              0
# https://agt.fandom.com/wiki/CZN                                    0
# https://alberto-pants-usa.com/                                     0
# https://alexanderbaldwin.com/                                      0
# https://allengelhard.com/                                          0
# ...                                                              ...
# https://www.yum.com/                                               0
# https://www.zalecorp.com                                           0
# https://www.zimmer.com                                             0
# https://wwwint.progress-energy.com/                                0
# https://yrc.com/                                                   0
#
# [951 rows x 43 columns]

# %%
total_tags = final.T.sum()

# %%
good_links_list = list(total_tags[total_tags >= 2].index)
good_links_list
# Out:
# ['https://agt.fandom.com/wiki/CZN',
#  'https://alberto-pants-usa.com/',
#  'https://alexanderbaldwin.com/',
#  'https://allengelhard.com/',
#  'https://arcb.com/',
#  'https://archstone.org/',
#  'https://astoriabank.snb.com/',
#  'https://awest.com/',
#  'https://bowaterecu.org/',
#  'https://broadwing.energy/',
#  'https://bulbapedia.bulbagarden.net/wiki/Unova',
#  'https://cnf.cornell.edu/',
#  'https://coventryconnect.cvty.com/CoventryConnect/login.xhtml',
#  'https://dqeready.com/',
#  'https://escapefromtarkov.fandom.com/wiki/USEC',
#  'https://external-telecom-teldta.icims.com/',
#  'https://finance.yahoo.com/quote/GS?fr=sycsrp_catchall',
#  'https://finance.yahoo.com/quote/TXI/?fr=sycsrp_catchall',
#  'https://flyxo.com/',
#  'https://fnf.onl/',
#  'https://goodrich.co/',
#  'https://hughessupply.com/',
#  'https://investor.cbrlgroup.com/press-releases',
#  'https://ir.aksteel.com/',
#  'https://kundaliniresearchinstitute.org/',
#  'https://lockheedmartin.com/en-us/index.html/',
#  'https://millenniumchem.lookchem.com/',
#  'https://mirage.mgmresorts.com/en.html',
#  'https://myaccount.protective.com/mony',
#  'https://mybrightpoint.org/',
#  'https://natoli.com/',
#  'https://newirin.irinnews.org/',
#  'https://nstaronline.com/',
#  'https://oldrepublictitle.com/',
#  'https://omgicomics.com/',
#  'https://oneamerica.com/',
#  'https://onlinebanking.mtb.com/',
#  'https://pathmark.com/',
#  'https://pubmed.ncbi.nlm.nih.gov/26155959/',
#  'https://pubmed.ncbi.nlm.nih.gov/29581585/',
#  'https://saraleebread.com/',
#  'https://sierrahealthandlife.com/',
#  'https://stryker.com/us/en/index.html/',
#  'https://thepantry.org/',
#  'https://theshawgrp.com/',
#  'https://us.vwr.com/store/product/4694781/cellstar-tissue-culture-plates-greiner-bio-one',
#  'https://ustsinc.com/',
#  'https://watsonpharma.lookchem.com/',
#  'https://webmail.frontier.com/',
#  'https://whiterosemaths.com/',
#  'https://www.3com.com',
#  'https://www.53.com',
#  'https://www.L-3com.com',
#  'https://www.aam-us.org/',
#  'https://www.abbott.com',
#  'https://www.abbreviations.com/DKWD',
#  'https://www.abm.com',
#  'https://www.acehardware.com',
#  'https://www.acs-inc.com',
#  'https://www.acterna.com',
#  'https://www.acuitybrands.com',
#  'https://www.adamsresources.com/',
#  'https://www.adm.com/adm-worldwide',
#  'https://www.adobe.com',
#  'https://www.adp.com',
#  'https://www.advanceautoparts.com',
#  'https://www.ae.com',
#  'https://www.aep.com',
#  'https://www.aesc.org/',
#  'https://www.aetna.com',
#  'https://www.aflac.com',
#  'https://www.agcocorp.com',
#  'https://www.agway.com',
#  'https://www.aimco.com',
#  'https://www.airgas.com',
#  'https://www.airproducts.com',
#  'https://www.alaskaair.com',
#  'https://www.alaskaair.com/deals/EmailDealsSignup?lid=TAfooter:emaildeals',
#  'https://www.albertsons.com',
#  'https://www.alleghenyenergy.com',
#  'https://www.allergan.com',
#  'https://www.allete.com/',
#  'https://www.alliantenergy.com/',
#  'https://www.alliedwaste.com',
#  'https://www.allmerica.com',
#  'https://www.allstate.com',
#  'https://www.altria.com/',
#  'https://www.amazon.com',
#  'https://www.amazon.com/benches/s?k=benches',
#  'https://www.amctheatres.com',
#  'https://www.ameren.com',
#  'https://www.american-securities.com/en/companies/metaldyne',
#  'https://www.americanexpress.com',
#  'https://www.americangreetings.com',
#  'https://www.americanstandard.com',
#  'https://www.americastestkitchen.com/',
#  'https://www.americredit.com',
#  'https://www.amerigroup.com/',
#  'https://www.amerisourcebergen.com/',
#  'https://www.amfam.com',
#  'https://www.amgen.com',
#  'https://www.amica.com',
#  'https://www.amkor.com',
#  'https://www.anheuser-busch.com',
#  'https://www.anico.com',
#  'https://www.anixter.com',
#  'https://www.anntaylor.com',
#  'https://www.anthem.com',
#  'https://www.antheminc.com/AboutAnthemInc/CompanyHistory/PW_D015003.html',
#  'https://www.aon.com',
#  'https://www.aosmith.com',
#  'https://www.applied.com/',
#  'https://www.apria.com',
#  'https://www.aquilaboats.com/',
#  'https://www.aramark.com',
#  'https://www.archcoal.com',
#  'https://www.arrow.com',
#  'https://www.asburyauto.com/',
#  'https://www.ashland.com/',
#  'https://www.atanet.org/',
#  'https://www.atimetals.com/',
#  'https://www.atmel.com',
#  'https://www.att.com',
#  'https://www.att.com/',
#  'https://www.auto-owners.com',
#  'https://www.autoliv.com/',
#  'https://www.autonation.com',
#  'https://www.autozone.com',
#  'https://www.avaya.com',
#  'https://www.averydennison.com',
#  'https://www.avnet.com',
#  'https://www.avon.com',
#  'https://www.b2bgateway.net/trading-partner/uw-grocers/',
#  'https://www.bakerhughes.com',
#  'https://www.ball.com',
#  'https://www.bankofamerica.com',
#  'https://www.bankone.com',
#  'https://www.banta.ws/',
#  'https://www.bausch.com',
#  'https://www.baxter.com',
#  'https://www.bbandt.com',
#  'https://www.bbb.org/us/or/tualatin/profile/general-contractor/reliant-resources-llc-1296-22547535',
#  'https://www.bbvausa.com/sign-in.html',
#  'https://www.bc.com',
#  'https://www.bearstearns.com',
#  'https://www.beazer.com',
#  'https://www.beckmancoulter.com',
#  'https://www.bedbathandbeyond.com',
#  'https://www.belk.com',
#  'https://www.bellsouth.com',
#  'https://www.belo.com',
#  'https://www.bemis.com',
#  'https://www.bestbuy.com',
#  'https://www.beverlyreview.net/',
#  'https://www.bhhs.com/',
#  'https://www.biglots.com',
#  'https://www.biogen.com',
#  'https://www.biomet.com',
#  'https://www.bjs.com/',
#  'https://www.bloomberg.com/profile/company/FCH:US',
#  'https://www.bloomberg.com/profile/company/NCF:US',
#  'https://www.bloomberg.com/profile/company/SUG:US',
#  'https://www.bluelight.org/xf/',
#  'https://www.bmc.com',
#  'https://www.bmhc.com',
#  'https://www.bms.com',
#  'https://www.bn.com',
#  'https://www.bnsf.com/',
#  'https://www.bnymellon.com/',
#  'https://www.boeing.com',
#  'https://www.bordenchem.com',
#  'https://www.bostonscientific.com',
#  'https://www.boydgaming.com',
#  'https://www.briggsandstratton.com',
#  'https://www.brown-forman.com',
#  'https://www.brunswick.com/',
#  'https://www.bxp.com/',
#  'https://www.ca.com',
#  'https://www.cabotcorp.com/',
#  'https://www.cadence.com',
#  'https://www.calpine.com/',
#  'https://www.campbellsoup.com',
#  'https://www.capitalone.com',
#  'https://www.cardinal.com',
#  'https://www.caremark.com/',
#  'https://www.carlisle.com',
#  'https://www.caseys.com',
#  'https://www.cdc.gov/vaccines/programs/vfc/index.html',
#  'https://www.cdw.com',
#  'https://www.centerpointenergy.com',
#  'https://www.centex.com',
#  'https://www.centurytel.com',
#  'https://www.ceridian.com',
#  'https://www.championhomes.com/',
#  'https://www.chicagotribune.com/',
#  'https://www.chiquita.com',
#  'https://www.chrobinson.com',
#  'https://www.chs.net',
#  'https://www.chubb.com',
#  'https://www.cigna.com',
#  'https://www.cinergy.com',
#  'https://www.cinfin.com',
#  'https://www.cintas.com',
#  'https://www.circuitcity.com',
#  'https://www.cisco.com',
#  'https://www.cisco.com/c/en/us/training-events/training-certifications/certifications/cyberops.html',
#  'https://www.cit.com',
#  'https://www.citigroup.com',
#  'https://www.citizensbank.com/HomePage.aspx',
#  'https://www.ckr.com',
#  'https://www.claytonhomes.com/',
#  'https://www.clorox.com',
#  'https://www.cmc.com/',
#  'https://www.cmsenergy.com',
#  'https://www.coat.com',
#  'https://www.coca-cola.com',
#  'https://www.coca-colacompany.com/',
#  'https://www.cokeconsolidated.com/',
#  'https://www.colgate.com',
#  'https://www.comcast.com',
#  'https://www.comenity.net/goodysonline',
#  'https://www.comerica.com',
#  'https://www.commerceinsurance.com',
#  'https://www.company-histories.com/Concord-EFS-Inc-Company-History.html',
#  'https://www.company-histories.com/Conseco-Inc-Company-History.html',
#  'https://www.company-histories.com/GenCorp-Inc-Company-History.html',
#  'https://www.company-histories.com/Metris-Companies-Inc-Company-History.html',
#  'https://www.company-histories.com/ScientificAtlanta-Inc-Company-History.html',
#  'https://www.company-histories.com/Tesoro-Petroleum-Corporation-Company-History.html',
#  'https://www.company-histories.com/The-Dial-Corp-Company-History.html',
#  'https://www.company-histories.com/UICI-Company-History.html',
#  'https://www.company-histories.com/WestPoint-Stevens-Inc-Company-History.html',
#  'https://www.compuware.com',
#  'https://www.conagra.com',
#  'https://www.conedison.com',
#  'https://www.constellation.com/',
#  'https://www.coopertire.com',
#  'https://www.coors.com',
#  'https://www.corning.com',
#  'https://www.cornproducts.com',
#  'https://www.costco.com',
#  'https://www.cox.com',
#  'https://www.craneco.com/home/default.aspx',
#  'https://www.crbard.com/medical/Professionals/Product-Concentrations/Bowel-Gastric-Management',
#  'https://www.csc.com',
#  'https://www.cskauto.com',
#  'https://www.csx.com',
#  'https://www.cummins.com',
#  'https://www.cunamutual.com',
#  'https://www.cvs.com',
#  'https://www.cvs.com/content/longs',
#  'https://www.cytec.com',
#  'https://www.daisytek.ae/',
#  'https://www.dana.com',
#  'https://www.darden.com',
#  'https://www.davita.com',
#  'https://www.deanfoods.com',
#  'https://www.deere.com',
#  'https://www.dell.com',
#  'https://www.delmonte.com',
#  'https://www.delta.com',
#  'https://www.deluxe.com',
#  'https://www.dentsply.com',
#  'https://www.devonenergy.com/',
#  'https://www.dieboldnixdorf.com/',
#  'https://www.dillards.com',
#  'https://www.dish.com/',
#  'https://www.disney.com',
#  'https://www.dj.com',
#  'https://www.dnb.com',
#  'https://www.dnb.com/business-directory/company-profiles.dpl_inc.ba18f9e834a3ffd4e2cf225e44a887f4.html',
#  'https://www.dnb.com/business-directory/company-profiles.foamex_international_inc.a76e6edb5943cff55497716609eba415.html',
#  'https://www.dole.com',
#  'https://www.dollartree.com',
#  'https://www.dom.com',
#  'https://www.dominos.com',
#  'https://www.donlinrecano.com/Clients/bjs/Index',
#  'https://www.dovercorporation.com',
#  'https://www.dow.com',
#  'https://www.dreyers.com/',
#  'https://www.drhorton.com',
#  'https://www.drivparts.com/fmstorefront/federalmogul/en/USD/',
#  'https://www.dstsystems.com',
#  'https://www.dteenergy.com',
#  'https://www.duke-energy.com',
#  'https://www.dupont.com',
#  'https://www.duraauto.com/',
#  'https://www.dynegy.com',
#  'https://www.ea.com',
#  'https://www.earthlink.net',
#  'https://www.eastman.com',
#  'https://www.eaton.com',
#  'https://www.ebworld.com',
#  'https://www.ecolab.com',
#  'https://www.eds.com',
#  'https://www.elcompanies.com',
#  'https://www.elpaso.com',
#  'https://www.emc.com',
#  'https://www.emerson.com/en-us',
#  'https://www.encompasshealth.com/',
#  'https://www.encyclopedia.com/reference/trade-magazines/aol-time-warner',
#  'https://www.encyclopedia.com/social-sciences-and-law/economics-business-and-labor/businesses-and-occupations/handleman-company',
#  'https://www.energizer.com',
#  'https://www.entergy.com',
#  'https://www.enterpriseproducts.com/',
#  'https://www.eqoffice.com/',
#  'https://www.equityapartments.com',
#  'https://www.erieinsurance.com',
#  'https://www.etrade.com',
#  'https://www.exeloncorp.com',
#  'https://www.express-scripts.com',
#  'https://www.exxonmobil.com',
#  'https://www.fairchildsemi.com',
#  'https://www.familydollar.com',
#  'https://www.fanniemae.com',
#  'https://www.fcx.com/',
#  'https://www.fdsrx.com/',
#  'https://www.federatedinsurance.com',
#  'https://www.fedex.com',
#  'https://www.firstam.com',
#  'https://www.firstcobalt.com/',
#  'https://www.firstdata.com',
#  'https://www.firstenergycorp.com',
#  'https://www.firsttennessee.com',
#  'https://www.fiserv.com',
#  'https://www.fisherscientific.com',
#  'https://www.fleetwoodrv.com/',
#  'https://www.flowersfoods.com',
#  'https://www.flowserve.com',
#  'https://www.fluor.com',
#  'https://www.fmc.gov/',
#  'https://www.fmglobal.com',
#  'https://www.ford.com',
#  'https://www.fortunebrands.com',
#  'https://www.fplgroup.com',
#  'https://www.furniture.com/brands',
#  'https://www.futureceuticals.com/truserv-whole-food-servings',
#  'https://www.gannett.com',
#  'https://www.gapinc.com',
#  'https://www.gateway.com',
#  'https://www.gd.com',
#  'https://www.gdwtowbars.com/en/',
#  'https://www.ge.com',
#  'https://www.gem.wiki/Mirant',
#  'https://www.generalcable.com/',
#  'https://www.generalmills.com',
#  'https://www.gentech.global/',
#  'https://www.genzyme.com',
#  'https://www.ggc.edu/',
#  'https://www.giant.com',
#  'https://www.gillette.com',
#  'https://www.glic.com',
#  'https://www.gm.com',
#  'https://www.goodyear.com',
#  'https://www.gosafeguard.com/',
#  'https://www.gp.com',
#  'https://www.grace.com',
#  'https://www.grainger.com',
#  'https://www.graniteconstruction.com/',
#  'https://www.greenpoint.com/',
#  'https://www.grey.com/',
#  'https://www.griffon.com/',
#  'https://www.group1auto.com',
#  'https://www.guidant.com',
#  'https://www.halliburton.com',
#  'https://www.harley-davidson.com',
#  'https://www.harleysvillegroup.com',
#  'https://www.harman.com',
#  'https://www.harrahs.com',
#  'https://www.harris.com',
#  'https://www.harsco.com',
#  'https://www.hasbro.com',
#  'https://www.hayes-lemmerz.com',
#  'https://www.hbfuller.com',
#  'https://www.hcahealthcare.com',
#  'https://www.hcr-manorcare.com',
#  'https://www.healthinsuranceproviders.com/mamsi-health-insurance-company-health-insurance-review/',
#  'https://www.heinz.com/',
#  'https://www.henryschein.com',
#  'https://www.hercrentals.com/us.html',
#  'https://www.hermanmiller.com',
#  'https://www.hersheys.com',
#  'https://www.hess.com',
#  'https://www.hewittrad.com/',
#  'https://www.hillenbrand.com/',
#  'https://www.hilton.com',
#  'https://www.homedepot.com',
#  'https://www.honeywell.com',
#  'https://www.hopkinsmedicine.org/health/conditions-and-diseases/staphylococcal-scalded-skin-syndrome',
#  'https://www.hormel.com/',
#  'https://www.hosthotels.com/',
#  'https://www.hp.com',
#  'https://www.hrblock.com',
#  'https://www.hubbell.com',
#  'https://www.hubgroup.com',
#  'https://www.humana.com',
#  'https://www.huntington.com',
#  'https://www.ibm.com',
#  'https://www.idt.net',
#  'https://www.ielectrica.com/',
#  'https://www.iff.com',
#  'https://www.igt.com/',
#  'https://www.ikon.com',
#  'https://www.imc.com/us/',
#  'https://www.imperialsugar.com',
#  'https://www.ingles-markets.com/',
#  'https://www.ingrammicro.com',
#  'https://www.insight.com',
#  'https://www.intel.com',
#  'https://www.intuit.com',
#  'https://www.investopedia.com/terms/a/arms.asp',
#  'https://www.investopedia.com/terms/q/quintile.asp',
#  'https://www.irena.org/ocean',
#  'https://www.ironmountain.com',
#  'https://www.itw.com',
#  'https://www.jabil.com',
#  'https://www.jackinthebox.com',
#  'https://www.jacobs.com',
#  'https://www.janus.com',
#  'https://www.jbhunt.com',
#  'https://www.jcpenney.net',
#  'https://www.jnj.com',
#  'https://www.jny.com',
#  'https://www.joann.com',
#  'https://www.johnhancock.com/index.html',
#  'https://www.johnsoncontrols.com',
#  'https://www.jpmorganchase.com',
#  'https://www.kbhome.com',
#  'https://www.kelloggs.com',
#  'https://www.kellyservices.com',
#  'https://www.kennametal.com',
#  'https://www.keybank.com',
#  'https://www.khov.com',
#  'https://www.kiewit.com/',
#  'https://www.kimball.com',
#  'https://www.kimberly-clark.com',
#  'https://www.kindredhealthcare.com',
#  'https://www.kingpharm.com',
#  'https://www.kla-tencor.com',
#  'https://www.kodak.com',
#  'https://www.kofc.org',
#  'https://www.kohls.com',
#  'https://www.kroger.com',
#  'https://www.la-z-boy.com/',
#  'https://www.labcorp.com',
#  'https://www.landolakesinc.com',
#  'https://www.landstar.com/',
#  'https://www.lear.com',
#  'https://www.leggett.com',
#  'https://www.level3.com',
#  'https://www.levistrauss.com/',
#  'https://www.lexmark.com',
#  'https://www.lfg.com',
#  'https://www.libertymutual.com',
#  'https://www.lilly.com',
#  'https://www.lithia.com',
#  'https://www.lizclaiborne.com',
#  'https://www.lnt.com',
#  'https://www.lowes.com',
#  'https://www.lowes.com/',
#  'https://www.lpcorp.com',
#  'https://www.lubrizol.com',
#  'https://www.lyondell.com',
#  'https://www.magellanhealth.com',
#  'https://www.manitowoc.com',
#  'https://www.manpower.com',
#  'https://www.markelcorp.com',
#  'https://www.marketwatch.com/investing/index/spx',
#  'https://www.marriott.com',
#  'https://www.marsh.com/us/home.html',
#  'https://www.martinmarietta.com/',
#  'https://www.masco.com',
#  'https://www.massmutual.com',
#  'https://www.mattel.com',
#  'https://www.maytag.com',
#  'https://www.mccormick.com',
#  'https://www.mcdonalds.com',
#  'https://www.mckesson.com',
#  'https://www.meadwestvaco.com',
#  'https://www.medtronic.com',
#  'https://www.mellon.com',
#  'https://www.menswearhouse.com',
#  'https://www.merck.com',
#  'https://www.mercuryinsurance.com',
#  'https://www.meritor.com/',
#  'https://www.merriam-webster.com/dictionary/Fleming',
#  'https://www.merriam-webster.com/dictionary/analog',
#  'https://www.merriam-webster.com/dictionary/countrywide',
#  'https://www.merriam-webster.com/dictionary/household',
#  'https://www.metlife.com',
#  'https://www.mgic.com',
#  'https://www.mgm.com',
#  'https://www.mheducation.com/',
#  'https://www.michaelfoods.com',
#  'https://www.michaels.com',
#  'https://www.micorpcustom.com/',
#  'https://www.micron.com',
#  'https://www.minnesotamutual.com',
#  'https://www.ml.com',
#  'https://www.mmc.com',
#  'https://www.mmm.com',
#  'https://www.mmoh.com',
#  'https://www.mohawkind.com',
#  'https://www.molex.com',
#  'https://www.monaco-online.com',
#  'https://www.montana-dakota.com/',
#  'https://www.morganstanley.com',
#  'https://www.motorola.com',
#  'https://www.mpsgroup.com',
#  'https://www.mt.com',
#  'https://www.murphyoilcorp.com',
#  'https://www.mutualofomaha.com',
#  'https://www.nacco.com',
#  'https://www.nadaguides.com/Motorcycles/2021/Kawasaki/KRF1000AMFNL-TERYX-KRX100-999cc',
#  'https://www.natfuel.com',
#  'https://www.nationalcar.com/en/home.html',
#  'https://www.nationalcityca.gov/',
#  'https://www.nationalgridus.com/',
#  'https://www.nationwide.com',
#  'https://www.navistar.com',
#  'https://www.ncr.com',
#  'https://www.neimanmarcus.com',
#  'https://www.newegg.com/LSI-Logic/BrandStore/ID-87081',
#  'https://www.newellbrands.com/',
#  'https://www.newmont.com',
#  'https://www.newyorklife.com',
#  'https://www.nextel.com',
#  'https://www.nicor.com',
#  'https://www.nike.com',
#  'https://www.njresources.com',
#  'https://www.nortek.com/',
#  'https://www.northropgrumman.com',
#  'https://www.northwestern.edu/',
#  'https://www.northwesternmutual.com',
#  'https://www.novell.com',
#  'https://www.nrucfc.org',
#  'https://www.nscorp.com',
#  'https://www.ntllaboratory.com/',
#  'https://www.ntrs.com',
#  'https://www.nu.edu/',
#  'https://www.nucor.com',
#  'https://www.nvidia.com',
#  'https://www.nytco.com/',
#  'https://www.o-i.com',
#  'https://www.ocas.ca/what-we-do/ontariocolleges',
#  'https://www.officedepot.com',
#  'https://www.officemax.com',
#  'https://www.oge.com',
#  'https://www.olin.com/',
#  'https://www.omnicare.com',
#  'https://www.oneok.com',
#  'https://www.optimum.net/',
#  'https://www.oracle.com',
#  'https://www.oracle.com/storage/tape-storage/',
#  'https://www.oreillyauto.com',
#  'https://www.oshkoshcorp.com/',
#  'https://www.outback.com',
#  'https://www.owens-minor.com',
#  'https://www.owenscorning.com',
#  'https://www.pacer.co.uk/',
#  'https://www.pacificare.com',
#  'https://www.pacificlife.com',
#  'https://www.packagingcorp.com',
#  'https://www.pactiv.com',
#  'https://www.pall.com',
#  'https://www.parker.com/',
#  'https://www.parkplace.com',
#  'https://www.pattersondental.com',
#  'https://www.paychex.com',
#  'https://www.payless.com/',
#  'https://www.pbg.com',
#  'https://www.pcconnection.com',
#  'https://www.peabodyenergy.com/',
#  'https://www.pencorp.com/',
#  'https://www.penntraffic.com/',
#  'https://www.pentair.com',
#  'https://www.peoplesoft.com',
#  'https://www.pepboys.com',
#  'https://www.pepco.com/',
#  'https://www.pepsico.com',
#  'https://www.perkinelmer.com',
#  'https://www.petco.com',
#  'https://www.petsmart.com',
#  'https://www.pfgc.com',
#  'https://www.pfizer.com',
#  'https://www.pfizer.com/about/history/pfizer_pharmacia',
#  'https://www.pg.com',
#  'https://www.pgecorp.com',
#  'https://www.phoenixwealthmgmt.com/',
#  'https://www.pier1.com',
#  'https://www.pilgrims.com/',
#  'https://www.pitneybowes.com',
#  'https://www.plainsallamerican.com/',
#  'https://www.pnc.com',
#  'https://www.polaris.com/en-us/',
#  'https://www.polo.com',
#  'https://www.polyone.com',
#  'https://www.popular.com/',
#  'https://www.ppg.com',
#  'https://www.pplweb.com',
#  'https://www.praxair.com',
#  'https://www.premcor.com/',
#  'https://www.primedianetwork.com/',
#  'https://www.principal.com',
#  'https://www.priorityhealthcare.org/',
#  'https://www.progressive.com',
#  'https://www.protective.com',
#  'https://www.provident.bank/',
#  'https://www.prudential.com',
#  'https://www.pse.com',
#  'https://www.pseg.com',
#  'https://www.publix.com',
#  'https://www.pulte.com',
#  'https://www.pvh.com',
#  'https://www.qualcomm.com',
#  'https://www.quantaservices.com/',
#  'https://www.questdiagnostics.com',
#  'https://www.qwest.com',
#  'https://www.radian.com/',
#  'https://www.radioshack.com/',
#  'https://www.rayonier.com',
#  'https://www.raytheon.com',
#  'https://www.rd.com',
#  'https://www.reebok.com',
#  'https://www.referenceforbusiness.com/history2/37/Mail-Well-Inc.html',
#  'https://www.regalcinemas.com',
#  'https://www.regions.com',
#  'https://www.regiscorp.com/',
#  'https://www.rentacenter.com',
#  'https://www.republicservices.com',
#  'https://www.rhi.com',
#  'https://www.richmondamerican.com',
#  'https://www.riteaid.com',
#  'https://www.riverwoodcenter.org/',
#  'https://www.rjf.com',
#  'https://www.rockwell.com',
#  'https://www.rockwellcollins.com',
#  'https://www.rossstores.com',
#  'https://www.rpminc.com',
#  'https://www.rrdonnelley.com',
#  'https://www.rsac.com/',
#  'https://www.russellcorp.com',
#  'https://www.ryder.com',
#  'https://www.ryerson.com/',
#  'https://www.ryland.com',
#  'https://www.sabre.com/',
#  'https://www.safeco.com',
#  'https://www.safeway.com',
#  'https://www.saic.com',
#  'https://www.salliemae.com',
#  'https://www.sanmina.com',
#  'https://www.santanderbank.com/',
#  'https://www.sbc.com',
#  'https://www.scanaenergy.com/',
#  'https://www.sce.com/',
#  'https://www.schiffvitamins.com/pages/airborne',
#  'https://www.scholastic.com',
#  'https://www.sci-corp.com',
#  'https://www.scotts.com',
#  'https://www.scripps.org/',
#  'https://www.seagate.com/support/by-product/maxtor/',
#  'https://www.sealedair.com',
#  'https://www.sealy.com',
#  'https://www.sears.com',
#  'https://www.selective.com',
#  'https://www.sempra.com',
#  'https://www.sentry.com',
#  'https://www.sequa.com/',
#  'https://www.sgi.com',
#  'https://www.sherwin.com',
#  'https://www.shopko.com',
#  'https://www.siebel.com',
#  'https://www.sierrapacificmortgage.com/',
#  'https://www.sigmaaldrich.com',
#  'https://www.silgan.com/',
#  'https://www.sjm.com',
#  'https://www.smithfieldfoods.com',
#  'https://www.smithoptics.com/',
#  'https://www.solectron.com',
#  'https://www.solutia.com',
#  'https://www.sonicautomotive.com',
#  'https://www.sonoco.com',
#  'https://www.southernco.com',
#  'https://www.southtrust.com/',
#  'https://www.southwest.com',
#  'https://www.spectrum.com/',
#  'https://www.spherion.com',
#  'https://www.sprint.com',
#  'https://www.stancorpfinancial.com',
#  'https://www.standardpacifichomes.com',
#  'https://www.staples.com',
#  'https://www.starbucks.com',
#  'https://www.starwood.com',
#  'https://www.statefarm.com',
#  'https://www.staterbros.com',
#  'https://www.statestreet.com',
#  'https://www.steelcase.com',
#  'https://www.steinmart.com',
#  'https://www.stewart.com',
#  'https://www.stpaul.gov/',
#  'https://www.sungardas.com/en-us/',
#  'https://www.sunh.com',
#  'https://www.sunocoinc.com',
#  'https://www.suntrust.com',
#  'https://www.supervalu.com',
#  'https://www.sweetheart.com',
#  'https://www.swgas.com',
#  'https://www.swifttrans.com',
#  'https://www.symbol.com',
#  'https://www.synovus.com',
#  'https://www.sysco.com',
#  'https://www.systemaxsolutions.com/',
#  'https://www.tatravelcenters.com',
#  'https://www.tcfbank.com',
#  'https://www.techdata.com',
#  'https://www.tecoenergy.com',
#  'https://www.teleflex.com',
#  'https://www.tellabs.com/',
#  'https://www.tenethealth.com',
#  'https://www.tenneco.com/',
#  'https://www.teradyne.com',
#  'https://www.textron.com',
#  'https://www.the-sun.com/news/',
#  'https://www.thehartford.com',
#  'https://www.thermofisher.com/us/en/home.html',
#  'https://www.therousecompany.com',
#  'https://www.thorindustries.com',
#  'https://www.thrivent.com',
#  'https://www.ti.com',
#  'https://www.tiaa-cref.org',
#  'https://www.tiffany.com',
#  'https://www.timberland.com',
#  'https://www.timken.com',
#  'https://www.titan.com',
#  'https://www.tjx.com',
#  'https://www.tollbrothers.com',
#  'https://www.torchmarkcorp.com',
#  'https://www.toro.com',
#  'https://www.towerautomotive.com',
#  'https://www.toysrus.com',
#  'https://www.tractorsupply.com/',
#  'https://www.trump.com',
#  'https://www.txu.com/company/why-txu-energy/about-us.aspx',
#  'https://www.tyson.com',
#  'https://www.ufpi.com',
#  'https://www.ugicorp.com',
#  'https://www.uhaul.com',
#  'https://www.uhsinc.com',
#  'https://www.unfi.com',
#  'https://www.unisys.com',
#  'https://www.united.com',
#  'https://www.unitedautoinsurance.com/',
#  'https://www.unitedhealthgroup.com',
#  'https://www.unitedrentals.com',
#  'https://www.unitrin.com',
#  'https://www.unumprovident.com',
#  'https://www.ups.com',
#  'https://www.urbandictionary.com/define.php?term=bdk',
#  'https://www.usaa.com',
#  'https://www.usainteractive.net/',
#  'https://www.usairways.com',
#  'https://www.usbank.com',
#  'https://www.usg.com',
#  'https://www.usoncology.com',
#  'https://www.utc.com',
#  'https://www.valero.com/',
#  'https://www.valspar.com',
#  'https://www.valuecityfurniture.com/',
#  'https://www.vectren.com',
#  'https://www.verisign.com',
#  'https://www.veritas.com',
#  'https://www.verizon.com',
#  'https://www.viacom.com',
#  'https://www.viad.com/business-units/overview/default.aspx',
#  'https://www.vno.com',
#  'https://www.volt.com/',
#  'https://www.vulcanmaterials.com/',
#  'https://www.wachovia.com',
#  'https://www.walgreens.com',
#  'https://www.walgreens.com/topic/duane-reade/duane-reade.jsp',
#  'https://www.walkerind.com/',
#  'https://www.wallace.com',
#  'https://www.wamu.com',
#  'https://www.washpostco.com',
#  'https://www.watsco.com/',
#  'https://www.wbrc.com/',
#  'https://www.wcicommunities.com',
#  'https://www.wellsfargo.com',
#  'https://www.wendys.com',
#  'https://www.werner.com',
#  'https://www.wesco.com/',
#  'https://www.westcorp.net/',
#  'https://www.westerndigital.com',
#  'https://www.weyerhaeuser.com',
#  'https://www.wfscorp.com',
#  'https://www.whirlpoolcorp.com',
#  'https://www.whitelabs.com/yeast-single?id=102&type=YEAST',
#  'https://www.wholefoods.com',
#  'https://www.williams.com',
#  'https://www.winn-dixie.com',
#  'https://www.wise-energy.com/',
#  'https://www.wm.com',
#  'https://www.worthingtonindustries.com',
#  'https://www.wpsrhd.com/',
#  'https://www.wrigley.com',
#  'https://www.wyndham.com',
#  'https://www.xerox.com',
#  'https://www.yellowcorp.com',
#  'https://www.yellowpages.com/chicago-il/sports-authority',
#  'https://www.york.com',
#  'https://www.yum.com/',
#  'https://www.zalecorp.com',
#  'https://www.zimmer.com',
#  'https://yrc.com/']

# %%
bad_links_list = list(total_tags[total_tags < 2].index)
bad_links_list = [x.split('//', 1) for x in bad_links_list]
bad_links_list = [x[1] for x in bad_links_list]
bad_links_list
# Out:
# ['3myms.eaglegl.com/default.asp',
#  'apps.apple.com/us/app/honi-game-for-couples/id1053412028',
#  'brconsultinginc.com/',
#  'careers.zionsbancorp.com/',
#  'clevelandhistorical.org/items/show/241',
#  'comdisco.net/',
#  'commission.saksincorporated.com/',
#  'docweb.wgint.com/webtop/component/main',
#  'en.wikipedia.org/wiki/Support-vector_machine',
#  'en.wikipedia.org/wiki/Tecumseh',
#  'fmc-technologies.com/',
#  'github.com/landam',
#  'gpcconnect.genpt.com/webcenter/portal/system/Home',
#  'hollywoodvideo.com/',
#  'hrss.spartanstores.com/hrss/home.html',
#  'investors.westernmidstream.com/',
#  'jp-financial.com/',
#  'myaccess.ipaper.com/',
#  'nbindustrial.org/stanley-works',
#  'opc.org/',
#  'plumcreekseniors.com/',
#  'rxisk.org/post-ssri-sexual-dysfunction-pssd/',
#  'shop.nordstrom.com/',
#  'support.microsoft.com/en-us/windows/setting-up-a-wireless-network-in-windows-97914e31-3aa4-406d-cef6-f1629e2c3721',
#  'twec-or.org/',
#  'usstn.com/',
#  'www.abercrombie.com/shop/us',
#  'www.agilent.com/',
#  'www.aig.com',
#  'www.alcoa.com/',
#  'www.alpinegroup.com/',
#  'www.amd.com/en',
#  'www.amerusoilfieldsolutions.com/',
#  'www.amrcaseinfo.com/',
#  'www.apachecorp.com/',
#  'www.apccchgo.org/',
#  'www.apple.com/',
#  'www.appliedmaterials.com/',
#  'www.armstrong.com/',
#  'www.barrlab.com/',
#  'www.bd.com/en-us',
#  'www.bearingpoint.com/en-us/',
#  'www.bizapedia.com/nc/rjr-holding-llc.html',
#  'www.brinker.com/',
#  'www.brownsshoes.com/en/home',
#  'www.cbrands.com/',
#  'www.cdi-corp.com/',
#  'www.chevrontexacocards.com/Chevron/',
#  'www.clearchannel.com',
#  'www.compuserve.com/',
#  'www.conocophillips.com/',
#  'www.contactpsc.com/',
#  'www.continental.com/en',
#  'www.cooper-cameron.com/',
#  'www.crowncork.com/',
#  'www.danaher.com/',
#  'www.ebay.com/',
#  'www.emcorgroup.com/',
#  'www.exide.com/',
#  'www.expeditors.com/',
#  'www.facebook.com/BellMicro/',
#  'www.facebook.com/UsFreightwaysInc',
#  'www.ferro.com/',
#  'www.footlocker-inc.com/',
#  'www.freddiemac.com/',
#  'www.frk-ae.com/',
#  'www.frx-inc.com/',
#  'www.gatx.com/wps/wcm/connect/GATX/GATX_SITE/Home',
#  'www.ghvgroup.com/',
#  'www.glchemical.com/',
#  'www.goldkistfarms.com/',
#  'www.graybar.com/',
#  'www.greatplainsenergy.com/homepage',
#  'www.greif.com/',
#  'www.heihotels.com/',
#  'www.hmacorp.com/',
#  'www.ibanknorth.com/',
#  'www.instagram.com/shopsimon/',
#  'www.interpublic.com/',
#  'www.itt.com/home',
#  'www.kellwood.com/',
#  'www.landandfarm.com/search/Illinois/Farm-for-sale/',
#  'www.lb.com/',
#  'www.leggmason.com',
#  'www.lehman.edu/',
#  'www.lennoxinternational.com',
#  'www.libertymedia.com/',
#  'www.marinerhealthcare.com/',
#  'www.masseyenergyco.com/',
#  'www.mbia.com/',
#  'www.microsoft.com/en-us/',
#  'www.multifoods.us/',
#  'www.nblenergy.com/',
#  'www.nisource.com/',
#  'www.nvrinc.com/',
#  'www.omnicomgroup.com/',
#  'www.oxhp.com/',
#  'www.oxy.com/',
#  'www.paccar.com/',
#  'www.pinnaclewest.com/Home/default.aspx',
#  'www.piosrestaurant.com/',
#  'www.pnm.com/',
#  'www.potlatchdeltic.com/',
#  'www.precast.com/',
#  'www.prideinternational.org/',
#  'www.providian.com',
#  'www.questar-corp.com/',
#  'www.roundys.com/',
#  'www.schwab.com/',
#  'www.seaboardcorp.com/',
#  'www.sec.gov/Archives/edgar/data/85704/000095014403013556/g86231e10vk.htm',
#  'www.siemens-healthineers.com/laboratory-diagnostics/dade-behring-siemens',
#  'www.snapon.com/',
#  'www.target.com/',
#  'www.templeinland.com/',
#  'www.terex.com/',
#  'www.termlifeamerica.com/unioncentral.html',
#  'www.tnb.com/',
#  'www.triadhospitals.com/',
#  'www.turbos.bwauto.com/',
#  'www.uniteddefense.com/',
#  'www.unitedstations.com/',
#  'www.universalcorp.com/',
#  'www.up.com/',
#  'www.varcopumper.com/',
#  'www.vishay.com/',
#  'www.visteon.com/',
#  'www.walmart.com/',
#  'www.wchoiceinc.com/about-us',
#  'www.weismarkets.com/',
#  'www.wglholdings.com/contact',
#  'www.wilcomm.com/',
#  'www.williams-sonomainc.com/',
#  'www.wordreference.com/es/translation.asp?tranword=WR',
#  'www.wyethusa.com/',
#  'www.xcelenergy.com',
#  'wwwint.progress-energy.com/']

# %%
final.sum()
# Out:
# GTM exists                         466
# Adobe Ananlytics Exists            227
# Google Universal Exists            671
# Adobe Launch Exists                161
# Adobe DTM Exists                    21
# Tealium TMS Exists                  76
# Ensighten Exists                    24
# GA4 Exists                         109
# Mixpanel Exists                      3
# Heap Exists                         14
# Amplitude Exists                     2
# Snowplow Exists                      9
# Adobe Target Exists                136
# Google Optimize Exists              84
# Optimizely Exists                   27
# Monetate Exists                     17
# Visual Website Optimizer Exists     15
# Adobe Audience Manager Exists      305
# Oracle BlueKai                     136
# Salesforce DMP                     112
# Nielsen DMP Exists                  92
# Lotame Crowd Control Exists         63
# Lytics Exists                        0
# Segment Exists                       0
# Tealium CDP Exists                  76
# TrustArc Exists                     42
# OneTrust Exists                    137
# ContentSquare Exists                 0
# FullStory Exists                    20
# Google Analytics Exists            681
# Adobe and Google Analytics         125
# Adobe and Tealium TMS               41
# Adobe and GTM                       44
# Adobe and Ensighten                 14
# Adobe and Adobe DTM                 19
# Adobe and Adobe Target             118
# Google and Tealium TMS              51
# Google and GTM                     437
# Google and Ensighten                17
# Google and Adobe DTM                 7
# Google and Google Optimize          81
# GA + Google Optimize + GTM          71
# AA + Adobe Target + Adobe DTM        7
# dtype: int64

# %%
def grab_top_link(text):
    search = 'http://www.bing.com/search?q=' + text
  
    # Fetch the URL data using requests.get(url),
    # store it in a variable, request_result.
    r = requests.get(search)

    soup = bs4.BeautifulSoup(r.text, "html.parser")

    result_div = soup.find_all('div', attrs = {'class': 'ZINbbc'})

    links = []
    titles = []
    descriptions = []
    for r in result_div:
        # Checks if each element is present, else, raise exception
        try:
            link = r.find('a', href = True)
            title = r.find('div', attrs={'class':'vvjwJb'}).get_text()
            description = r.find('div', attrs={'class':'s3v9rd'}).get_text()

            # Check to make sure everything is present before appending
            if link != '' and title != '' and description != '': 
                links.append(link['href'])
                titles.append(title)
                descriptions.append(description)
        # Next loop if one element is not present
        except:
            continue
    import re   

    to_remove = []
    clean_links = []
    for i, l in enumerate(links):
        clean = re.search('\/url\?q\=(.*)\&sa',l)

        # Anything that doesn't fit the above pattern will be removed
        if clean is None:
            to_remove.append(i)
            continue
        clean_links.append(clean.group(1))

    # Remove the corresponding titles & descriptions
    for x in to_remove:
        del titles[x]
        del descriptions[x]
        
    top_link = clean_links[0]
    i = 0
    wiki = 0
    while 'wikipedia' in top_link or 'history' in top_link:
        wiki += 1
        i+=1
        top_link = clean_links[i]
    return [top_link, wiki]

# %%
grab_top_link('aam')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-255751e36e05> in <module>
# ----> 1 grab_top_link('aam')
#
# <ipython-input-27-5fff93f81cb5> in grab_top_link(text)
#      46         del descriptions[x]
#      47
# ---> 48     top_link = clean_links[0]
#      49     i = 0
#      50     wiki = 0
#
# IndexError: list index out of range

# %%
company_good = {}
company_bad = []
last_req = time.time()
for company in Forbes.Name[:1]:
    link = grab_top_link(company)
    if link[1] < 0:
        company_good[company] = link[1]
    else:
        company_good[company] = link[1]
    
    now = time.time()
    delay = last_req + 0.600 - now
    last_req = now
    if delay >= 0:
        time.sleep(delay)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3aa0d9521539> in <module>
#       2 company_bad = []
#       3 last_req = time.time()
# ----> 4 for company in Forbes.Name[:1]:
#       5     link = grab_top_link(company)
#       6     if link[1] < 0:
#
# NameError: name 'Forbes' is not defined

# %%
good_links = []
bad_links = []
last_req = time.time()
for company in bad_links_list:
    try:
        grab_top_link(company)
        if grab_top_link(company)[1] > 0:
            bad_links.append(grab_top_link(company)[0])
        else:
            good_links.append(grab_top_link(company)[0])
    except:
        print('Nope')
    
    now = time.time()
    delay = last_req + 0.600 - now
    last_req = now
    if delay >= 0:
        time.sleep(delay)
# Out:
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope

# %%
good_links
# Out:
# ['https://apps.apple.com/us/app/honi-game-for-couples/id1053412028',
#  'https://brconsultinginc.com/',
#  'https://careers.zionsbancorp.com/',
#  'https://comdisco.net/',
#  'https://commission.saksincorporated.com/',
#  'https://docweb.wgint.com/webtop',
#  'https://fmc-technologies.com/',
#  'https://github.com/landam',
#  'https://www.napaconnect.com/',
#  'http://hollywoodvideo.com/',
#  'http://hrss.spartanstores.com/',
#  'http://investors.westernmidstream.com/',
#  'https://jp-financial.com/',
#  'https://login.ipaper.com/',
#  'https://nbindustrial.org/stanley-works',
#  'https://www.opc.org/',
#  'http://plumcreekseniors.com/',
#  'https://rxisk.org/post-ssri-sexual-dysfunction-pssd/',
#  'https://www.nordstrom.com/',
#  'https://support.microsoft.com/en-us/windows/setting-up-a-wireless-network-in-windows-97914e31-3aa4-406d-cef6-f1629e2c3721',
#  'https://twec-or.org/',
#  'https://usstn.com/',
#  'https://www.abercrombie.com/shop/us',
#  'https://www.agilent.com/',
#  'https://www.aig.com/',
#  'https://www.alcoa.com/',
#  'https://www.alpinegroup.com/',
#  'https://www.amd.com/en',
#  'http://www.amerusoilfieldsolutions.com/',
#  'http://www.amrcaseinfo.com/',
#  'https://www.apachecorp.com/',
#  'https://www.apccchgo.org/',
#  'https://www.apple.com/',
#  'https://www.appliedmaterials.com/',
#  'http://www.armstrong.com/',
#  'https://www.barrlab.com/',
#  'https://www.bd.com/en-us',
#  'https://www.bearingpoint.com/en-us/',
#  'https://www.bizapedia.com/nc/rjr-holding-llc.html',
#  'https://www.brinker.com/']

# %%
bad_links
# Out:
# ['https://machinelearningmastery.com/support-vector-machines-for-machine-learning/']

# %%
len(good_links)
# Out:
# 40

# %%
len(bad_links)
# Out:
# 1

# %%
len(bad_links_list)
# Out:
# 137

# %%
len(good_links_list)
# Out:
# 814

# %%
search = 'http://www.bing.com/search?q=' + 'aam'

# Fetch the URL data using requests.get(url),
# store it in a variable, request_result.
r = requests.get(search)

soup = bs4.BeautifulSoup(r.text, "html.parser")

result_div = soup.find_all('div', attrs = {'class': 'ZINbbc'})

links = []
titles = []
descriptions = []
for r in result_div:
    # Checks if each element is present, else, raise exception
    try:
        link = r.find('a', href = True)
        title = r.find('div', attrs={'class':'vvjwJb'}).get_text()
        description = r.find('div', attrs={'class':'s3v9rd'}).get_text()

        # Check to make sure everything is present before appending
        if link != '' and title != '' and description != '': 
            links.append(link['href'])
            titles.append(title)
            descriptions.append(description)
    # Next loop if one element is not present
    except:
        continue
import re   

to_remove = []
clean_links = []
for i, l in enumerate(links):
    clean = re.search('\/url\?q\=(.*)\&sa',l)

    # Anything that doesn't fit the above pattern will be removed
    if clean is None:
        to_remove.append(i)
        continue
    clean_links.append(clean.group(1))

# Remove the corresponding titles & descriptions
for x in to_remove:
    del titles[x]
    del descriptions[x]

top_link = clean_links[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-d9998d9be7c4> in <module>
#      45     del descriptions[x]
#      46
# ---> 47 top_link = clean_links[0]
#
# IndexError: list index out of range

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:web="http://schemas.live.com/Web/"><script type="text/javascript">//<![CDATA[
# si_ST=new Date
# //]]></script><head><!--pc--><title>aam - Bing</title><meta content="text/html; charset=utf-8" http-equiv="content-type"/><link href="/search?format=rss&amp;q=aam" rel="alternate" title="XML" type="text/xml"/><link href="/search?format=rss&amp;q=aam" rel="alternate" title="RSS" type="application/rss+xml"/><link href="/sa/simg/favicon-2x.ico" rel="shortcut icon"/><script type="text/javascript">//<![CDATA[
# _G={Region:"US",Lang:"en-US",ST:(typeof si_ST!=='undefined'?si_ST:new Date),Mkt:"en-US",RevIpCC:"us",RTL:false,Ver:"41",IG:"F41D0DFAD9DF4FC69C6395E7C4088FE9",EventID:"DC2B293096A7422182EB52A4297264C9",MN:"SERP",V:"web",P:"SERP",DA:"Ch1b",CID:"3BF87753FAA5636519E46794FB0D6246",SUIH:"UgmURIO7CIP6oxeDm93aQQ",adc:"b_ad",EF:{bmasynctrigger:1},gpUrl:"\/fd\/ls\/GLinkPing.aspx?" }; _G.lsUrl="/fd/ls/l?IG="+_G.IG+"&CID="+_G.CID ;curUrl="http:\/\/www.bing.com\/search";function si_T(a){ if(document.images){_G.GPImg=new Image;_G.GPImg.src=_G.gpUrl+'IG='+_G.IG+'&CID='+_G.CID+'&'+a;}return true;};_G.SID='2F2BBB12E4EE6C7D3F98ABD5E5466D5B';/*!DisableJavascriptProfiler*/
# 0;
# ;/*!DisableJavascriptProfiler*/
# 0;/*!DisableJavascriptProfiler*/
# 0;
# ;
# //]]></script><style type="text/css">a{z:1}a{z:1}.sw_ddbk:after,.sw_ddw:after,.sw_ddgn:after,.sw_poi:after,.sw_poia:after,.sw_play:after,.sw_playa:after,.sw_playd:after,.sw_playp:after,.sw_st:after,.sw_sth:after,.sw_ste:after,.sw_st2:after,.sw_plus:after,.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after,.sw_arwh:after,.sw_close:after,.sb_pagN:after,.sb_pagP:after,.sw_up:after,.sw_down:after,.b_expandToggle:after,.sw_calc:after,.sw_fbi:after,.sw_twi:after,.b_fLogo:after,.b_cm:after,.sw_rmore:after,.sw_tpo:after,.sw_tpoa:after,.sw_lpoi:after,.sw_skp:after{position:relative}.sw_ddbk:after,.sw_ddw:after,.sw_ddgn:after,.sw_poi:after,.sw_poia:after,.sw_play:after,.sw_playa:after,.sw_playd:after,.sw_playp:after,.sw_st:after,.sw_sth:after,.sw_ste:after,.sw_st2:after,.sw_plus:after,.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after,.sw_arwh:after,.sw_close:after,.sb_pagN:after,.sb_pagP:after,.sw_up:after,.sw_down:after,.b_expandToggle:after,.sw_calc:after,.sw_fbi:after,.sw_twi:after,.b_fLogo:after,.b_cm:after,.sw_rmore:after,.sw_tpo:after,.sw_tpoa:after,.sw_lpoi:after,.sw_skp:after{content:url(/rp/oSe0wGyrskgMIOQlhww-3erlOYU.png)}.sw_ddbk,.sw_ddw,.sw_ddgn,.sw_poi,.sw_poia,.sw_play,.sw_playa,.sw_playd,.sw_playp,.sw_st,.sw_sth,.sw_ste,.sw_st2,.sw_plus,.sw_tpcg,.sw_tpcw,.sb_clrhov,.sw_arwh,.sb_pagN,.sb_pagP,.sw_up,.sw_down,.b_expandToggle,.sw_calc,.sw_fbi,.sw_twi,.b_fLogo,.b_cm,.sw_rmore,.sw_tpo,.sw_tpoa,.sw_lpoi,.sw_skp,.actExpander span{position:relative;display:inline-block;overflow:hidden;direction:ltr}.sw_ddbk:after,.sw_ddw:after,.sw_ddgn:after,.sw_poi:after,.sw_poia:after,.sw_play:after,.sw_playa:after,.sw_playd:after,.sw_playp:after,.sw_st:after,.sw_sth:after,.sw_ste:after,.sw_st2:after,.sw_plus:after,.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after,.sw_arwh:after,.sb_pagN:after,.sb_pagP:after,.sw_up:after,.sw_down:after,.b_expandToggle:after,.sw_calc:after,.sw_fbi:after,.sw_twi:after,.b_fLogo:after,.b_cm:after,.sw_rmore:after,.sw_tpo:after,.sw_tpoa:after,.sw_lpoi:after,.sw_skp:after{display:inline-block;transform:scale(.5)}.sw_tpcg,.b_expandToggle,.b_fLogo{display:block}.sw_play,.sw_playa,.sw_playd,.sw_playp,.sw_skp,.sw_fbi,.sw_twi{height:16px;width:16px}.sw_play:after{transform-origin:-630px -44px}.sw_playa:after{transform-origin:-666px -44px}.sw_playd:after{transform-origin:-702px -44px}.sw_playp:after{transform-origin:-738px -44px}.sw_skp:after{transform-origin:-1290px -36px}.sw_fbi:after{transform-origin:-594px -44px}.sw_twi:after{transform-origin:-1290px 0}.sw_st,.sw_sth,.sw_ste,.sw_st2{height:12px;width:12px}.sw_st:after{transform-origin:-1070px -62px}.sw_st2:after{transform-origin:-1126px -62px}.sw_sth:after{transform-origin:-1154px -62px}.sw_ste:after{transform-origin:-1098px -62px}.sw_arwh{height:11px;width:14px}a:hover .sw_arwh.b_invert:after{transform-origin:-926px -64px}.sw_arwh:after{transform-origin:-894px -64px}.sw_ddbk,.sw_ddw,.sw_ddgn{height:4px;width:7px}.sw_ddbk:after,.sw_ddw:after{transform-origin:-532px -64px}.sw_ddgn:after{transform-origin:-512px -64px}.sw_tpcg,.sw_tpcw,.sw_tpcbk{height:10px;width:10px}.sw_tpcg:after,.sw_tpcw:after,.sw_tpcbk:after{transform-origin:-352px -64px}.sw_tpcg:hover:after,.sw_tpcg:active:after,.sw_tpcg:focus:after{-webkit-transform-origin:-376px -64px;-ms-transform-origin:-376px -64px;transform-origin:-376px -64px}.sw_plus{height:8px;width:8px}.sw_plus:after{transform-origin:-552px -64px}.sw_plus:hover:after,.sw_plus:active:after,.sw_plus:focus:after{transform-origin:-572px -64px}.b_expandToggle,.sw_up,.sw_down{height:8px;width:12px}.b_expandToggle:after,.sw_up:after,.sw_down:after{transform-origin:-456px -64px}.sw_up:after{transform-origin:-400px -64px}*:hover>.sw_up:after,*:active>.sw_up:after,*:focus>.sw_up:after{transform-origin:-428px -64px}*:hover>.sw_down:after,*:active>.sw_down:after,*:focus>.sw_down:after{transform-origin:-484px -64px}.b_icon,.sw_poi,.sw_poia{width:20px;height:20px;z-index:0}.sw_poi:after,.sw_poia:after{position:absolute;top:0;left:0;transform-origin:-594px 0;z-index:-1 ...
# var amd,define,require;(function(n){function e(n,i,u){t[n]||(t[n]={dependencies:i,callback:u},r(n))}function r(n){if(n){if(n)return u(n)}else{if(!f){for(var r in t)u(r);f=!0}return i}}function u(n){var s,e;if(i[n])return i[n];if(t.hasOwnProperty(n)){var h=t[n],f=h.dependencies,l=h.callback,a=r,o={},c=[a,o];if(f.length<2)throw"invalid usage";else if(f.length>2)for(s=f.slice(2,f.length),e=0;e<s.length;e++)c.push(u(s[e]));return l.apply(this,c),i[n]=o,o}}var t={},i={},f=!1;n.define=e;n.require=r})(amd||(amd={}));define=amd.define;require=amd.require;var _w=window,_d=document,sb_ie=window.ActiveXObject!==undefined,sb_i6=sb_ie&&!_w.XMLHttpRequest,_ge=function(n){return _d.getElementById(n)},_qs=function(n,t){return t=typeof t=="undefined"?_d:t,t.querySelector?t.querySelector(n):null},sb_st=function(n,t){return setTimeout(n,t)},sb_rst=sb_st,sb_ct=function(n){clearTimeout(n)},sb_gt=function(){return(new Date).getTime()},sj_gx=function(){return sb_i6?new ActiveXObject("MSXML2.XMLHTTP"):new XMLHttpRequest};_w.sj_ce=function(n,t,i){var r=_d.createElement(n);return t&&(r.id=t),i&&(r.className=i),r};_w.sj_cook=_w.sj_cook||{get:function(n,t){var i=_d.cookie.match(new RegExp("\\b"+n+"=[^;]+")),r;return t&&i?(r=i[0].match(new RegExp("\\b"+t+"=([^&]*)")),r?r[1]:null):i?i[0]:null}};_w.sk_merge||(_w.sk_merge=function(n){_d.cookie=n});_w.bbe="A:rms:answers:Shared:BingCore.Bundle";define("fallback",["require","exports"],function(n,t){function f(){return function(){for(var r,h,c,t=[],n=0;n<arguments.length;n++)t[n]=arguments[n];if(r=s(arguments.callee),u&&(h=e(r),h.toString()!=f().toString()))return h.apply(null,arguments);c=i[r].q;t[0]==="onPP"&&o();c.push(t)}}function s(n){for(var t in i)if(i[t].h===n)return t}function e(n,t){for(var u,e=n.split("."),i=_w,r=0;r<e.length;r++)u=e[r],typeof i[u]=="undefined"&&t&&(i[u]=r===e.length-1?f():{}),i=i[u];return i}function o(){var e=i["rms.js"].q,o,f,r,n,s,u,t;if(e.length>0)for(o=!1,f=0;f<e.length;f++){for(r=e[f],n=0;n<r.length;n++)if(s=_w.bbe,u=r[n][s],u||(u=r[n]["A:rmsBu0"]),u){t=_d.createElement("script");t.setAttribute("data-rms","1");t.setAttribute("crossorigin","anonymous");t.src=u;t.type="text/javascript";setTimeout(function(){_d.body.appendChild(t)},0);r.splice(n,1);o=!0;break}if(o)break}}function h(){var n,t,f;for(u=!1,n=0;n<r.length;n++)t=r[n],f=e(t,!0),i[t]={h:f,q:[]}}function c(){for(var t,n=0;n<r.length;n++){var o=r[n],s=i[o].q,h=e(o);for(t=0;t<s.length;t++)h.toString()!==f().toString()&&h.apply(null,s[t])}u=!0}function l(n,t,i,r){n&&((n===_w||n===_d||n===_d.body)&&t=="load"?_w.sj_evt.bind("onP1",i,!0):n.addEventListener?n.addEventListener(t,i,r):n.attachEvent?n.attachEvent("on"+t,i):n["on"+t]=i)}t.__esModule=!0;t.replay=void 0;var r=["rms.js","sj_evt.bind","sj_evt.fire","sj_jb","sj_wf","sj_cook.get","sj_cook.set","sj_pd","sj_sp","sj_be","sj_go","sj_ev","sj_ue","sj_evt.unbind","sj_et","Log.Log","sj_mo","sj_so"],i={},u=!1;_w.fb_is=o;t.replay=c;h();_w.sj_be=l});function lb(){_w.si_sendCReq&&sb_st(_w.si_sendCReq,800);_w.lbc&&_w.lbc()};(function(){function n(n){n=sb_ie?_w.event:n;(!n.altKey||n.ctrlKey||n.shiftKey)&&(n.key&&n.key==="Enter"||n.keyCode&&n.keyCode===13)&&_w.si_ct(sb_ie?n.srcElement:n.target,!1,n,"enter")}sj_be(document,"keydown",n,!1)})();(function(){function n(n){_w.si_ct(sb_ie?_w.event.srcElement:n.target,!1,_w.event||n)}sj_be(document,"mousedown",n,!1)})();/*!DisableJavascriptProfiler*/
# 0;/*!DisableJavascriptProfiler*/
# 0;/*!DisableJavascriptProfiler*/
# 0;ClTrCo={furl:!0};var ctcc=0,clc=_w.ClTrCo||{};_w.si_ct=function(n,t,i,r){var u,o,e,s,f,a,h,c,l;if(clc.SharedClickSuppressed)return!0;u="getAttribute";try{for(;n!==document.body;n=n.parentNode){if(!n||n===document||n[u]("data-noct"))break;if(o=(n.tagName==="A"||n[u]("data-clicks"))&&(n[u]("h")||n[u]("data-h"))||n[u]("_ct"),o){e=n[u]("_ctf");s=-1;i&&(i.type==="keydown"?s=-2:i.button!=null&&(s=i.button));e&&_w[e]||(e="si_T");e==="si_T"&&(f=n[u]("href"),_G!==undefined&&_G.EF!==undefined&&_G.EF.newtabredironclicktracking===1&&f.indexOf("/newtabredir")==0?(a=new RegExp("[?&]?url=([^&]*)(&|$)"),h=f.match(a),h&&(f=f.indexOf("&be=1")>=0?encodeURIComponent(atob(decodeURIComponent(h[1]))):h[1])):f=encodeURIComponent(n[u]("href")),clc.furl&&!n[u]("data-private")?o+="&url="+f:clc.mfurl&&(o+="&abc="+f));r&&(o+="&source="+r);c="";clc.mc&&(c="&c="+ctcc++);l="&"+o+c;_w.si_sbwu(l)||_w[e]&&_w[e](l,n,i,s);break}if(t)break}}catch(v){_w.SharedLogHelper?SharedLogHelper.LogWarning("clickEX",null,v):(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"CI.Warning","FID":"CI","Name":"JSWarning","Text":'+v.message+"}]"}return!0};_w.si_sbwu||(_w.si_sbwu=function(){return!1}),function(){_w._G&&(_G.si_ct_e="click")}();
# //]]></script><script crossorigin="anonymous" src="/rp/GWzm2T8lV9tveFS_P21il3q15kM.gz.js" type="text/javascript"></script><script type="text/javascript">//<![CDATA[
# var wlc_d = 1500, wlc_t =63769059882;;var sj_log=function(n,t,i){var r=new RegExp('"',"g");(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"'+n+'","FID":"CI","Name":"'+t+'","Text":"'+escape(i.replace(r,""))+'"}]'};(function(n,t,i){function r(n){var t=n.indexOf("#");return t===-1?n:n.substring(0,t)}function u(){var n=location.href;n.indexOf("ajaxserp=0")==-1&&r(n)!==r(i)&&location.replace(n+"&ajf=100")}function f(n){n&&n.length>1&&n[1]&&(i=n[1])}sj_be(n,t,u,!1);var e="ajax.state.update";sj_evt.bind(e,f,1);sj_evt.bind("ajaxReady",function(){sj_ue(n,t,u,!1);sj_evt.unbind(e,f)})})(_w,"popstate",location.href);_G.JCache=1;;var perf;(function(n){function f(n){return i.hasOwnProperty(n)?i[n]:n}function e(n){var t="S";return n==0?t="P":n==2&&(t="M"),t}function o(n){for(var c,i=[],t={},r,l=0;l<n.length;l++){var a=n[l],o=a.v,s=a.t,h=a.k;s===0&&(h=f(h),o=o.toString(36));s===3?i.push(h+":"+o):(r=t[s]=t[s]||[],r.push(h+":"+o))}for(c in t)t.hasOwnProperty(c)&&(r=t[c],i.push(e(+c)+':"'+r.join(",")+'"'));return i.push(u),i}for(var r=["redirectStart","redirectEnd","fetchStart","domainLookupStart","domainLookupEnd","connectStart","secureConnectionStart","connectEnd","requestStart","responseStart","responseEnd","domLoading","domInteractive","domContentLoadedEventStart","domContentLoadedEventEnd","domComplete","loadEventStart","loadEventEnd","unloadEventStart","unloadEventEnd","firstChunkEnd","secondChunkStart","htmlEnd","pageEnd","msFirstPaint"],u="v:1.1",i={},t=0;t<r.length;t++)i[r[t]]=t;n.compress=o})(perf||(perf={}));window.perf=window.perf||{},function(n){n.log=function(t,i){var f=n.compress(t),r;f.push('T:"CI.Perf",FID:"CI",Name:"PerfV2"');var e="/fd/ls/lsp.aspx?",o="sendBeacon",h="<E><T>Event.ClientInst<\/T><IG>"+_G.IG+"<\/IG><TS>"+i+"<\/TS><D><![CDATA[{"+f.join(",")+"}]\]><\/D><\/E>",s="<ClientInstRequest><Events>"+h+"<\/Events><STS>"+i+"<\/STS><\/ClientInstRequest>",u=!_w.navigator||!navigator[o];if(!u)try{navigator[o](e,s)}catch(c){u=!0}u&&(r=sj_gx(),r.open("POST",e,!0),r.setRequestHeader("Content-Type","text/xml"),r.send(s))}}(window.perf);var perf;(function(n){function a(){return c(Math.random()*1e4)}function o(){return y?c(f.now())+l:+new Date}function v(n,r,f){t.length===0&&i&&sb_st(u,1e3);t.push({k:n,v:r,t:f})}function p(n){return i||(r=n),!i}function w(n,t){t||(t=o());v(n,t,0)}function b(n,t){v(n,t,1)}function u(){var u,f;if(t.length){for(u=0;u<t.length;u++)f=t[u],f.t===0&&(f.v-=r);t.push({k:"id",v:e,t:3});n.log(t,o());t=[];i=!0}}function k(){r=o();e=a();i=!1;sj_evt.bind("onP1",u)}var s="performance",h=!!_w[s],f=_w[s],y=h&&!!f.now,c=Math.round,t=[],i=!1,l,r,e;h?l=r=f.timing.navigationStart:r=_w.si_ST?_w.si_ST:+new Date;e=a();n.setStartTime=p;n.mark=w;n.record=b;n.flush=u;n.reset=k;sj_be(window,"load",u,!1);sj_be(window,"beforeunload",u,!1)})(perf||(perf={}));_w.si_PP=function(n,t,i){var r,o,l,h,e,c;if(!_G.PPS){for(o=["FC","BC","SE","TC","H","BP",null];r=o.shift();)o.push('"'+r+'":'+(_G[r+"T"]?_G[r+"T"]-_G.ST:-1));var u=_w.perf,s="navigation",r,f=i||_w.performance&&_w.performance.timing;if(f&&u){if(l=f.navigationStart,u.setStartTime(l),l>=0)for(r in f)h=f[r],typeof h=="number"&&h>0&&r!=="navigationStart"&&r!==s&&u.mark(r,h);u.record("nav",s in f?f[s]:performance[s].type)}e="connection";c="";_w.navigator&&navigator[e]&&(c=',"net":"'+navigator[e].type+'"',navigator[e].downlinkMax&&(c+=',"dlMax":"'+navigator[e].downlinkMax+'"'));_G.PPImg=new Image;_G.PPImg.src=_G.lsUrl+'&Type=Event.CPT&DATA={"pp":{"S":"'+(t||"L")+'",'+o.join(",")+',"CT":'+(n-_G.ST)+',"IL":'+_d.images.length+"}"+(_G.C1?","+_G.C1:"")+c+"}"+(_G.P?"&P="+_G.P:"")+(_G.DA?"&DA="+_G.DA:"")+(_G.MN?"&MN="+_G.MN:"");_G.PPS=1;sb_st(function(){u&&u.flush();sj_evt.fire("onPP");sj_evt.fire(_w.p1)},1)}};_w.onbeforeunload=function(){si_PP(new Date,"A")};sj_evt.bind("ajax.requestSent",function(){window.perf&&perf.reset()});var BM=BM||{},adrule="."+_G.adc+" > ul";BM.rules={".b_scopebar":[0,0,0],".b_logo":[-1,-1,0],".b_searchboxForm":[100,40,0],"#id_h":[-1,0,0],"#b_tween":[-1 ...
# //]]></script><script crossorigin="anonymous" src="/rp/EOGgDuLBglWZly5ymyLj9HPYfT8.gz.js" type="text/javascript"></script><script type="text/javascript">//<![CDATA[
# FallBackToDefaultProfilePic = function (e) { var new_element = document.createElement('span'); new_element.setAttribute('id', 'id_p'); new_element.setAttribute('class', 'sw_spd id_avatar'); new_element.setAttribute('aria-label', "Default Profile Picture"); var p = e.parentNode; p.replaceChild(new_element, e); };var sb_de=_d.documentElement;
# //]]></script></head><body onload="if(_w.lb)lb();"><header id="b_header"><form action="/search" class="" id="sb_form"><a class="b_logoArea" h="ID=SERP,5032.1" href="/?FORM=Z9FD1"><h1 aria-label="Go to Bing homepage" class="b_logo" title="Back to Bing search"></h1></a><div class="b_searchboxForm" role="search"><input aria-autocomplete="both" aria-label="Enter your search here - Search suggestions will show as you type" autocapitalize="off" autocomplete="off" autocorrect="off" class="b_searchbox b_softkey" dir="" id="sb_form_q" maxlength="1000" name="q" onfocus="_ge('b_header').className='b_focus';" spellcheck="false" type="search" value="aam"/><div class="sb_clrhov" data-sbtipx="Clear" id="sb_clt"><a aria-label="Clear text" href="javascript:void(0);" id="sw_clx" role="button" tabindex="0"><div class="sw_close"></div></a></div><span data-sbtip="Search using an on-screen keyboard" id="vkeyIcon"></span><div data-ep="0" data-evt="" data-iconpl="0" data-iid=".5064" data-ptn="Web" id="sbicom_loader" style="display:none"></div><div id="sb_search"><a h="ID=SERP,5033.1" href="javascript:void(0);" tabindex="-1"><div data-sbtip="Search the web" id="sb_go_par"><div class="sb_icon" id="b_icon_spyglass"></div><input class="b_searchboxSubmit" id="sb_form_go" name="go" tabindex="0" type="submit" value="Search"/></div></a></div><input id="sa_qs" name="qs" type="hidden" value="ds"/><input name="form" type="hidden" value="QBRE"/></div></form><div aria-label="Account Rewards and Preferences" data-priority="2" id="id_h" role="complementary"><a aria-controls="id_d" aria-expanded="false" aria-haspopup="true" class="id_button" data-clarity-mask="true" h="ID=SERP,5034.1" href="javascript:void(0);" id="id_l"><div> <span class="cbtn" data-appns="SERP" data-k="5066.1" data-wire="I;button_init;; |" id="CE5C16_1_btn"><input aria-label="" id="id_a" name="submit" type="submit" value="Sign in"/></span></div><span aria-hidden="true" id="id_n" style="display:none"></span><img alt="Profile Picture" aria-hidden="true" aria-label="Profile Picture" class="id_avatar sw_spd" data-alt="" data-src="..." id="id_p" onerror="FallBackToDefaultProfilePic(this)" src="..." style="display:none"/></a><span _iid="SERP.5051" id="id_d"></span><a aria-controls="bepfo" aria-expanded="false" aria-haspopup="true" aria-label="Microsoft Rewards" class="id_button" h="ID=SERP,5041.1" href="javascript:void(0)" id="id_rh" role="button"><span class="serp" id="id_rc">Rewards</span><span class="rwds_svg serp pc" id="rewards_header_icon serp"><span class="rhlined serp"></span><span class="rhfill serp"></span><svg id="rh_meter" xmlns="http://www.w3.org/2000/svg"><circle class="serp" cx="20" cy="20" id="rh_animcrcl" r="14" stroke-dasharray="88, 88" transform="rotate(-90,20,20)"></circle></svg></span></a><a class="b_hide" h="ID=SERP,5040.1" href="/rewards/dashboard" id="id_rwl"></a><span _ig="F41D0DFAD9DF4FC69C6395E7C4088FE9" _iid="SERP.5039" id="nc_iid"></span><a aria-controls="id_hbfo" aria-expanded="false" aria-haspopup="true" aria-label="Settings and quick links" class="idp_ham nohphbtop" h="ID=SERP,5049.1" href="javascript:void(0);" id="id_sc" role="button" tabindex="0"></a><span _iid="SERP.5050" aria-hidden="true" aria-labelledby="id_sc" class="slide_up nohpfo" id="id_hbfo" role="menu" tabindex="-1"></span></div><nav aria-label="Main menu" class="b_scopebar" role="navigation"><ul class="b_scopehide"><li class="b_active" data-menuurl="" id="b-scopeListItem-web"><a aria-current="page" h="ID=SERP,5025.1" href="/?scope=web&amp;FORM=HDRSC1" target="">All</a></li><li class="" data-menuurl="" id="b-scopeListItem-images"><a aria-current="false" h="ID=SERP,5026.1" href="/images/search?q=aam&amp;FORM=HDRSC2" target="_self">Images</a></li><li class="" data-menuurl="" id="b-scopeListItem-video"><a aria-current="false" h="ID=SERP,5027.1" href="/videos/search?q=aam&amp;FORM=HDRSC3" target="_self">Videos</a></li><li class="" data-menuurl="" id="b-scopeListItem-local"><a aria-current="false" h="ID=SERP,5028. ...
# var logMetaError=function(n){(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"CI.MetaError","FID":"CI","Name":"MetaJSError","Text":"'+escape(n)+'"}]'},getHref=function(){return location.href},regexEscape;try{regexEscape=function(n){return n.replace(/([.?*+^$&[\]\\(){}|<>-])/g,"\\$1")};function jsErrorHandler(n){var s,r,y,p,u,f,w,e,h,c,o;try{if(s="ERC",r=window[s],r=r?r+1:1,r===16&&(n=new Error("max errors reached")),r>16)return;window[s]=r;var l=n.error||n,b='"noMessage"',k=n.filename,d=n.lineno,g=n.colno,nt=n.extra,a=l.severity||"Error",tt=l.message||b,i=l.stack,t='"'+escape(tt.replace(/"/g,""))+'"',it=new RegExp(regexEscape(getHref()),"g");if(i){for(y=/\(([^\)]+):[0-9]+:[0-9]+\)/g,u={};(p=y.exec(i))!==null;)f=p[1],u[f]?u[f]++:u[f]=1;e=0;for(h in u)u[h]>1&&(c=regexEscape(h),w=new RegExp(c,"g"),i=i.replace(w,e),i+="#"+e+"="+c,e++);i=i.replace(it,"self").replace(/"/g,"");t+=',"Stack":"'+(escape(i)+'"')}if(k&&(t+=',"Meta":"'+escape(k.replace(it,"self"))+'"'),d&&(t+=',"Line":"'+d+'"'),g&&(t+=',"Char":"'+g+'"'),nt&&(t+=',"ExtraInfo":"'+nt+'"'),tt===b)if(a="Warning",t+=',"ObjectToString":"'+n.toString()+'"',JSON&&JSON.stringify)t+=',"JSON":"'+escape(JSON.stringify(n))+'"';else for(o in n)n.hasOwnProperty(o)&&(t+=',"'+o+'":"'+n[o]+'"');var rt=(new Date).getTime(),ut='"T":"CI.'+a+'","FID":"CI","Name":"JS'+a+'","Text":'+t+"",ft="<E><T>Event.ClientInst<\/T><IG>"+_G.IG+"<\/IG><TS>"+rt+"<\/TS><D><![CDATA[[{"+ut+"}]]\]><\/D><\/E>",et="<ClientInstRequest><Events>"+ft+"<\/Events><STS>"+rt+"<\/STS><\/ClientInstRequest>",v=new XMLHttpRequest;v.open("POST","/fd/ls/lsp.aspx?",!0);v.setRequestHeader("Content-Type","text/xml");v.send(et);typeof sj_evt!="undefined"&&sj_evt.fire("ErrorInstrumentation",t)}catch(ot){logMetaError("Failed to execute error handler. "+ot.message)}}window.addEventListener&&window.addEventListener("error",jsErrorHandler,!1);window.addEventListener||window.onerror||(window.onerror=function(n,t,i,r,u){var f="",e;typeof n=="object"&&n.srcElement&&n.srcElement.src?f="\"ScriptSrc = '"+escape(n.srcElement.src.replace(/'/g,""))+"'\"":(n=""+n,f='"'+escape(n.replace(/"/g,""))+'","Meta":"'+escape(t)+'","Line":'+i+',"Char": '+r,u&&u.stack&&(e=new RegExp(regexEscape(getHref()),"g"),f+=',"Stack":"'+escape(u.stack.replace(e,"self").replace(/"/g,"")+'"')));(new Image).src=_G.lsUrl+'&Type=Event.ClientInst&DATA=[{"T":"CI.GetError","FID":"CI","Name":"JSGetError","Text":'+f+"}]";typeof sj_evt!="undefined"&&sj_evt.fire("ErrorInstrumentation",f)})}catch(e){logMetaError("Failed to bind error handler "+e.message)};var sj_b=_d.body;0;(function(n){var i,r,t;if(document.querySelector){i=[];r="ad";function u(){var w=sb_gt(),l=document.documentElement,s=document.body,t=0,r=-1,b=l.clientHeight,a=["#b_results ."+_G.adc,".sb_adsWv2",".ads"],n,f,e,p,c,o,u;if(s){n=0;f=document.querySelector("#b_pole .pa_carousel_mlo");f&&(n=f.offsetHeight,r=f.offsetTop);var v=document.querySelector("#b_results #productAdCarousel"),h=document.querySelector("#b_results .pa_b_supertop"),y=document.querySelector("#b_results .bn_wide");for(h?(r=h.offsetTop,n=h.offsetHeight):y?n+=y.offsetHeight:v&&(n+=v.offsetHeight),t=n,e=0;e<a.length;e++)for(p=a[e],c=document.querySelectorAll(p),o=0;o<c.length;o++)u=c[o],u&&u.className.indexOf("b_adTop")!==-1&&(t+=u.offsetHeight,r===-1&&(r=u.offsetTop));t===0&&(t=-1);i=[r,t,l.clientWidth,b,s.offsetWidth,s.offsetHeight,sb_gt()-w]}}n?(t=n.onbeforefire,n.onbeforefire=function(){t&&t();u();n.mark(r,i)}):(t=si_PP,si_PP=function(){u();var n='"'+r+'":['+i.join()+"]";_G.C1=_G.C1?_G.C1+","+n:n;t.apply(null,[].slice.apply(arguments))})}})(_w.pp);_w.AM=["live.com","virtualearth.net","windows.net","onenote","hexun.com","dict.bing.com.cn","msn.com","variflight.com","bing.net","msftoffers.com","chinacloudapp.cn","cbsnews.com","swx.cdn.skype.com","swc.cdn.skype.com","latest-swx.cdn.skype.com","a.config.skype.com","b.config.skype.com","platform.bing.com","microsofttranslator.com","bing.com","facebook.net",".delve.office.com",".uservoice.com",".cd ...
# //]]></script><script type="text/javascript">//<![CDATA[
# _G.FCT=new Date;
# //]]></script><script type="text/javascript">//<![CDATA[
# _G.BCT=new Date;
# //]]></script><style type="text/css">a{z:1}#b_content a.b_LinksColorMD,#b_content a:visited.b_LinksColorMD{color:#1a73e8}.b_CursorProgress{cursor:progress}z{a:1}z{a:1}#b_results .b_algo .b_vlist2col.b_deep{color:#767676}#b_results .b_algo .b_vlist2col.b_deep,#b_results .b_algo .b_deep.b_moreLink{padding-left:12px}#b_results .b_algo .b_vlist2col.b_deep>ul:first-child{margin-right:0}#b_results .b_algo .b_vlist2col.b_deep>ul:nth-child(2){margin-left:48px}#b_results .b_algo .b_vlist2col.b_deep ul{width:274px}#b_results .b_algo form.b_externalSearch{margin-left:12px}z{a:1}.b_caption.b_snippetgobig p{font-size:18px;line-height:24px !important;color:#111}.b_algo.b_algoBorder{box-shadow:0 0 0 1px rgba(0,0,0,.05),0 2px 3px 0 rgba(0,0,0,.1);border-radius:6px}#b_results>li.b_algoBorder{margin-top:8px;padding-top:15px}#b_results>li.b_algoBorder.b_algo_feedback{margin-bottom:19px;position:relative}.b_gobig_feedback{position:absolute;right:19px;bottom:-21px;font-size:11px}#b_results>li.b_algoBorder.b_algo_feedback+li.b_ans.b_mop.b_mopb{margin-top:28px}#b_results .b_attribution .lock_icon .siz12{vertical-align:inherit;width:12px;height:12px;margin-right:4px}#b_results .b_attribution .secure_icon>svg{vertical-align:-10%;width:48px;height:16px;margin-right:4px}#b_results .b_attribution .secure_slug_icon>svg{vertical-align:-10%;width:48px;height:14px;margin-right:4px}a{a:1}p>.news_dt{color:#767676}.sb_doct_txt{color:#1a0dab;font-size:11px;line-height:21px;margin-right:3px;vertical-align:super}.sb_pagP_bp:after{-webkit-transform-origin:-1394px 0;transform-origin:-1394px 0}.sb_pagP_bp:hover:after,.sb_pagP_bp:active:after,.sb_pagP_bp:focus:after{-webkit-transform-origin:-1478px 0;transform-origin:-1478px 0}.sb_pagN_bp:after{-webkit-transform-origin:-1394px 0;transform-origin:-1394px 0}.sb_pagN_bp:hover:after,.sb_pagN_bp:active:after,.sb_pagN_bp:focus:after{-webkit-transform-origin:-1478px 0;transform-origin:-1478px 0}.sb_inactP:after,.sb_inactP:hover:after{-webkit-transform-origin:-1562px 0;transform-origin:-1562px 0}.b_pag a{display:block;text-align:center}.b_pag a.sb_bp{min-width:40px;margin-right:20px;line-height:42px}.b_pag a.sb_pagN,.b_pag a.sb_pagP{border:0;padding:1px}.b_pag a.sb_pagN_bp,.b_pag a.sb_pagP_bp{width:40px;height:40px;margin-top:0}.b_pag a.sb_bp.sb_inactP{min-width:38px}.b_pag a.sb_pagP_bp.sb_inactP{width:38px}.b_pag a.b_roths{-webkit-transform:rotate(180deg);transform:rotate(180deg)}.b_pag .sw_prev,.b_pag .sw_next{margin:2px}@media screen and (-ms-high-contrast:active){.sb_pagN:after,.sb_pagP:after{content:""}li.b_pag a.sb_pagN,li.b_pag a.sb_pagP{width:auto}li.b_pag a.b_roths{-webkit-transform:rotate(0deg);transform:rotate(0deg)}.b_pag .sw_next,.b_pag .sw_prev{display:block}}#mfa_root .fba_sbicn{background:url(/rp/oSe0wGyrskgMIOQlhww-3erlOYU.png) no-repeat -242px 0;transform:scale(.5)}#b_results>li#mfa_root{right:0;position:fixed;z-index:1011;background-color:transparent;pointer-events:none}#mfa_root .b_ds5{transform:none;transition:transform .4s cubic-bezier(.3,.55,.1,1),opacity .1s;opacity:1;z-index:1011;align-self:flex-end;pointer-events:initial;border-radius:50%;overflow:hidden}#mfa_root.b_fabHide .b_ds5{pointer-events:none;transform:translateX(30px);opacity:0}#mfa_root .b_ds5:active{opacity:.8}#mfa_root .mfa_btn{display:flex;align-items:center;justify-content:center;cursor:pointer}a{z:1}a{z:1}#b_results>li#mfa_root { padding: 40px; bottom: 0px; ; } #mfa_root .mfa_btn { background: #fff; width: 56px; height: 56px; }.b_ds5{box-shadow:0 0 0 1px rgba(0,0,0,.08),0 4px 12px 1px rgba(0,0,0,.2);-webkit-box-shadow:0 0 0 1px rgba(0,0,0,.08),0 4px 12px 1px rgba(0,0,0,.2)}a.b_ds5:hover,input.b_ds5:hover{box-shadow:0 0 0 1px rgba(0,0,0,.08),0 4px 14px 2px rgba(0,0,0,.24);-webkit-box-shadow:0 0 0 1px rgba(0,0,0,.08),0 4px 14px 2px rgba(0,0,0,.24)}#b_context.crhide,#b_mtp.crhide{display:none}#b_context.crinvis,#b_mtp.crinvis{visibility:hidden}#b_mtp{display:inline-block;visibility:hidden}#b_mtp:not(.crhide),#b_mtp *{display:inline-block; ...
# if (typeof DynScopes !== 'undefined') { DynScopes.init("", "", "marketplace:flights"); };_w.sched=_w.sched||function(){function r(t){n.push(t)}function u(n){return function(){_w.sched.schedule(n)}}function f(n){t.push(n)}function e(n,t){i[n]=t}var n=[],t=[],i={};return{register:r,wrapSchedule:u,schedule:f,reportCustomMetric:e,_ns:n,_reg:t,_cm:i}}();function ge_cl(n,t){var u,f,r,i;if(n){if(n.getElementsByClassName)return n.getElementsByClassName(t);for(u=n.getElementsByTagName("*"),f=[],r=0;r<u.length;r++)i=u[r],i&&i.className&&i.className.indexOf(t)!==-1&&f.push(i);return f}return[]};function sa_cl(n,t,i){if(n&&t){var r=n.className;i?r.indexOf(t)==-1&&(r=r.concat(" ",t)):r=r.replace(t,"");n.className=r}};var EntityPreviewConfig = { featureList: "", testHooks: false };
# //]]></script><script type="text/javascript">//<![CDATA[
# 0;var fab_config ={"fabStyle":1,"fabSbAction":"FocusSearchBox","fabSbActionHover":"None","fabSbActionData":"None","fabTooltip":""};;
# //]]></script><div id="b_content"><main aria-label="Search Results"><div class="null" id="b_tween"><span class="sb_count">16 results</span></div><ol class="" id="b_results"><li class="b_algo"><h2><a h="ID=SERP,5098.1" href="https://annualmeeting.aam-us.org/">American Alliance of Museums – 2021 <strong>AAM</strong> Annual Meeting ...</a></h2><div class="b_caption"><div class="b_attribution" u="0|5069|4591681070108037|IZBm2JbBzScoDn8ejMv4Y6cVt0Vqf40T"><cite>https://annualmeeting.<strong>aam</strong>-us.org</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5099.1"></span></span></div><p>The <strong>AAM</strong> Annual Meeting &amp; MuseumExpo is the only event of its scope and scale. It brings together museums of all types and sizes—from art and history museums to zoos and botanic gardens—to share ideas and make connections that are transformative.</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5110.1" href="https://mft.aam.com/">Server Login - American Axle</a></h2><div class="b_caption"><div class="b_attribution"><cite>https://mft.<strong>aam</strong>.com</cite></div><p>Log in. Username:: Forgot Username: Password:: Forgot Password</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5123.1" href="https://www.autosinnovate.org/">Transforming Personal Mobility | Alliance For Automotive ...</a></h2><div class="b_caption"><div class="b_attribution" u="2|5071|4801636250028701|Dk0IY6lCyKaHiHfFnMAGypk5qyOYm36z"><cite>https://www.autosinnovate.org</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5124.1"></span></span></div><p>Cleaner. Safer. Smarter. Formed by the 2020 combination of the <strong>Alliance of Automobile Manufacturers</strong> (Auto Alliance) and the Association of Global Automakers (Global Automakers), Auto Innovators is dedicated to propelling the unprecedented innovation that will make our lives better.</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5136.1" href="https://aam.amazon.in/">Amazon</a></h2><div class="b_caption"><div class="b_attribution"><cite>https://<strong>aam</strong>.amazon.in</cite></div><p>We would like to show you a description here but the site won’t allow us.</p><div class="b_factrow"><a h="ID=SERP,5278.1" href="https://www.bing.com/webmaster/info/missinginfo">Learn more</a></div></div></li><li class="b_algo"><h2><a h="ID=SERP,5149.1" href="https://www.americanmanufacturing.org/">Alliance for American Manufacturing</a></h2><div class="b_caption"><div class="b_attribution" u="4|5073|4821856956713731|knVwFnDn3UWQum51aCRgPB2AGPMPxUne"><cite>https://www.americanmanufacturing.org</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5150.1"></span></span></div><p>The Alliance for American Manufacturing (<strong>AAM</strong>) was founded in 2007 by leading domestic manufacturers and the United Steelworkers, North America’s largest industrial union, with a simple mission: strengthen American manufacturing through smart public policies.</p></div></li><li class="b_algo"><h2><a h="ID=SERP,5163.1" href="https://atlas.niu.edu/gwo/"><strong>AAM/GWO Mapwall</strong> - Northern Illinois University</a></h2><div class="b_caption"><div class="b_attribution" u="5|5074|4590040391942595|QWxW_lA28rQnTy9rfk1eYH3dPxXC5t5G"><cite>https://atlas.niu.edu/gwo</cite><span class="c_tlbxTrg"><span class="c_tlbxH" h="BASE:CACHEDPAGEDEFAULT" k="SERP,5164.1"></span></span></div><p><strong>AAM / GWO Mapwall</strong> Courtesy of Dr. Victor Gensini | NIU Department of Geographic and Atmospheric Sciences M R Profile by Latitude | 30 Day Archive: M R Profile Anomaly by Latitude | 30 Day Archive: M R Latest 30 Days: M R Latest 60 Days: M R Latest 90 Days: M R Latest 120 Days: M R Latest 150 Days: M R Latest 180 Days: M R Latest 365 Days: Latest 250 mb</p></div></li><li class="b_algo"><div class="b_title"><span class="sb_doct_txt b_float">[PDF]</span><h2><a h="ID=SERP,5176.1" href="https://www.faa.gov/about/office_org/headqu ...
# _w.keyMap={Content:"b_content",SearchForm:"sb_form",SBoxId:"sb_form_q",Notification:"b_notificationContainer",Identity:"id_h",Prefix:"b_",RmsDefer:"aRmsDefer",RmsKeys:["rms:answers:Shared:BingCore.Bundle","rms:answers:AjaxSerp:Ajax.Bundle","rms:answers:BoxModel:Framework"],AutoSug:"sa_as",FeaturePersist:1,LangSwitch:"langChange",ASContainer:"sw_as",Result:"b_results"};var searchForm,content;_G.JCache&&(searchForm=_ge(keyMap.SearchForm),_G.SRF=searchForm&&searchForm.outerHTML,content=_ge(keyMap.Content),content||(content=_ge("sw_content")),_G.CNT=content?content.outerHTML:null);(function(n,t){onload=function(){_G.BPT=new Date;n&&n();!_w.sb_ppCPL&&t&&sb_st(function(){t(new Date)},0)}})(_w.onload,_w.si_PP);_G!==undefined&&_G.EF!==undefined&&_G.EF.bmasynctrigger===1&&window.requestAnimationFrame!==undefined&&document.visibilityState!==undefined&&document.visibilityState==="visible"?requestAnimationFrame(function(){setTimeout(function(){BM.trigger()},0)}):BM.trigger();loadMultiKeyBoardScript=function(){_w.rms.js({'rms:answers:VisualSystem:MultiLingualKeyboardBundle':'\/rp\/hz4pLbkTii-0pmFFR7AN5z6RrMI.gz.js',d:1});};;sa_loader=function(){_w.rms.js({'rms:answers:AutoSuggest:AutoSug':'\/rp\/iH3So1ciV3VxXFzNvijxCffaHxg.gz.js',d:1});};;_w.rms.js({'A:0':0},{'A:rms:answers:Web:ClearSearchBox':'\/rp\/JDHEvZVDnqsG9UcxzgIdtGb6thw.gz.js'},{'A:1':1},{'A:rms:answers:MultimediaComponents:SearchByImageComponentLoader':'\/rp\/H0tBeYy8ok5qbeZq9Oge36K-zeo.gz.js'},{'A:2':2},{'A:rms:answers:Identity:BlueIdentityDropdownBootStrap':'\/rp\/P3LN8DHh0udC9Pbh8UHnw5FJ8R8.gz.js'},{'A:rms:answers:Identity:BlueIdentityHeader':'\/rp\/T_fuRJ5ONhzzZUcXzufvynXGXyQ.gz.js'},{'A:3':3},{'A:rms:answers:Identity:SnrWindowsLiveConnectBootstrap':'\/rp\/ozS3T0fsBUPZy4zlY0UX_e0TUwY.gz.js'},{'A:rms:answers:OrgId:SsoFrame':'\/rp\/Xp-HPHGHOZznHBwdn7OWdva404Y.gz.js'},{'A:4':4},{'A:rms:answers:Identity:ProfilePicturePostLoader':'\/rp\/MstqcgNaYngCBavkktAoSE0--po.gz.js'},{'A:rms:answers:Rewards:RewardsHeaderSVG':'\/rp\/B6z3MALNFEeBovQmI37aEJvT4eI.gz.js'},{'A:rms:answers:Rewards:RewardsNcHeaderBootstrap':'\/rp\/pNsvmKeHtE2msyItPeNI850_WaY.gz.js'},{'A:RewardsReportActivity':'\/rp\/7m655Ud2BRXxznIYtGVzYp1pj8s.gz.js'},{'A:rms:answers:Rewards:RewardsCreditRefresh':'\/rp\/beJXTKHqBtZtzQeUy_x4MrT0A54.gz.js'},{'A:rms:answers:Rewards:ModernReportActivity':'\/rp\/4nDVPiwNewi-PVpURd4B2bxHRok.gz.js'},{'A:rms:answers:Rewards:ReportActivityBootstrap':'\/rp\/5ZeCNP-uUJOft0EeiTJVHgcU_PU.gz.js'},{'A:5':5},{'A:rms:answers:Web:AlgoTitleColorOnMousedown':'\/rp\/hLIJkdTrOxcvwVdcjNc-Ci4kLok.gz.js'},{'A:rms:answers:Web:CursorProgressOnClick_Rebind':'\/rp\/-4lWPvsxE8kxJO-eEYkwR6dS34E.gz.js'},{'A:rms:answers:Web:CursorProgressOnClick':'\/rp\/e18WoGB0Fl3Fh_de5Qlf5D_DTk0.gz.js'},{'A:6':6},{'A:rms:answers:WebResult:WebResultToolbox':'\/rp\/JoVtU0YtyY9tw3IdM7NM0MLUXGk.gz.js'},{'A:rms:answers:VisualSystem:SearchFloatingActionButtonTriggering':'\/rp\/UMc3LQfNxSkvn2QdRt2WMsv397Y.gz.js'},{'A:rms:answers:VisualSystem:FloatingActionButtonCore':'\/rp\/LqBcF6Ml2TywK2INgNL-J_Ml5Rs.gz.js'},{'A:rms:answers:VisualSystem:SearchFloatingActionButton':'\/rp\/RL6HEoSHjZWll1BAzkMgFXLPLhI.gz.js'},{'A:7':7},{'A:rms:answers:VisualSystem:FullPageLightBox':'\/rp\/3cX0fkarz8qRcSjVy6NGt534djI.gz.js'},{'A:rms:answers:Web:SerpKeyboardNavigation_Selector':'\/rp\/iT_V8KBI7eC1TQv70SZIlBffTUA.gz.js'},{'A:rms:answers:Web:SerpKeyboardNavigation':'\/rp\/LE_d8dc_TAW7HlSuXKxKfy6Bg7I.gz.js'},{'A:8':8});;
# //]]></script><div id="aRmsDefer"><div style="display:none"><!--//<![CDATA[
# var ErrFuncs;(function(n){function i(n,i,r){t("Error",n,i,r)}function r(n,i,r){t("Warning",n,i,r)}function t(n,t,i,r){var u,f;if(r?(u=r,u.message+=" "+t):u=new Error(t),u.extra="manualError",i&&(u.extra+=" "+i),u.severity=n,f=_w.jsErrorHandler,f)f(u);else throw u;}n.LogError=i;n.LogWarning=r})(ErrFuncs||(ErrFuncs={}));JS={LogError:ErrFuncs.LogError,LogWarning:ErrFuncs.LogWarning};SharedLogHelper={LogError:ErrFuncs.LogError,LogWarning:ErrFuncs.LogWarning,LogFatalError:function(){return null},RegisterErrorFilter:function(){return null}};/*!DisableJavascriptProfiler*/
# 0;var FocusScrollToBTop;(function(){function i(){var i=t()-n;i>AwayTimeThreshold&&(_w.scrollTo(0,0),_w.sj_log&&sj_log("CI.ReturnTop","ReturnTop"+AwayTimeThreshold.toString(),"Triggered"),sj_evt.fire("focusTopScrollEnd"))}function r(){n=t()}function t(){return Math.round(Date.now()/1e3)}var n;sj_evt.bind("focusTopScrollStart",i);sj_evt.bind("focusTopBlur",r);sj_be(_w,"focus",function(){sj_evt.fire("focusTopScrollStart")});sj_be(_w,"blur",function(){sj_evt.fire("focusTopBlur")})})(FocusScrollToBTop||(FocusScrollToBTop={}));var Lib;(function(n){var t;(function(n){function u(n,t){var r,i;if(t==null||n==null)throw new TypeError("Null element passed to Lib.CssClass");if(n.indexOf)return n.indexOf(t);for(r=n.length,i=0;i<r;i++)if(n[i]===t)return i;return-1}function f(n,u){if(n==null)throw new TypeError("Null element passed to Lib.CssClass");if(!t(n,u))if(r&&n.classList)n.classList.add(u);else{var f=i(n)+" "+u;o(n,f)}}function e(n,f){var e,s,h;if(n==null)throw new TypeError("Null element passed to Lib.CssClass");t(n,f)&&(r&&n.classList?n.classList.remove(f):(e=i(n).split(" "),s=u(e,f),s>=0&&e.splice(s,1),h=e.join(" "),o(n,h)))}function s(n,i){if(n==null)throw new TypeError("Null element passed to Lib.CssClass");r&&n.classList?n.classList.toggle(i):t(n,i)?e(n,i):f(n,i)}function t(n,t){var f,e;if(n==null)throw new TypeError("Null element passed to Lib.CssClass");return r&&n.classList?n.classList.contains(t):(f=i(n),f)?(e=f.split(" "),u(e,t)>=0):!1}function h(n,t){var f,e,r,u,o;if(n.getElementsByClassName)return n.getElementsByClassName(t);for(f=n.getElementsByTagName("*"),e=[],r=0;r<f.length;r++)u=f[r],u&&(o=i(u),o&&o.indexOf(t)!==-1&&e.push(u));return e}function o(n,t){n instanceof SVGElement?n.setAttribute("class",t):n.className=t}function i(n){return n instanceof SVGElement?n.getAttribute("class"):n.className}var r=typeof document.body.classList!="undefined";n.add=f;n.remove=e;n.toggle=s;n.contains=t;n.getElementByClassName=h})(t=n.CssClass||(n.CssClass={}))})(Lib||(Lib={}));var MultiLingualKeyboardScriptLoader;(function(n){function u(t,u,f,e,o){n.Languages=t.split(",");n.Languages!==null&&n.Languages.length>0&&(r=n.Languages[0].split(":")[0]);n.EmojiEnabled=f;n.ExtendedKeyboardLayout=e;n.IsSettingsPage=o;n.EmojiEnabled&&sj_evt.bind("onP1",i,!0);n.KeyboardType=u}function i(){typeof MultiLingualKeyBoard=="undefined"||MultiLingualKeyBoard.prevSelectedLang!==r&&MultiLingualKeyBoard.KeyboardTypes.Tabbed!==n.KeyboardType?loadMultiKeyBoardScript():MultiLingualKeyBoard.initializeKeyboard()}function f(){n.KbdIconPressed=!0;e()?MultiLingualKeyBoard.closeKeyboard():i()}function e(){var n=_ge("keyboard");return n!==null&&(n.style.display==="block"||n.style.display==="")?!0:!1}var r="",t;n.EmojiEnabled=!1;n.ExtendedKeyboardLayout=!1;n.IsSettingsPage=!1;n.KbdIconPressed=!1;n.init=u;n.keyboardScriptLoader=i;t=_ge("vkeyIcon");t&&(t.className="vkeyRest",sj_be(t,"click",f))})(MultiLingualKeyboardScriptLoader||(MultiLingualKeyboardScriptLoader={}));MultiLingualKeyboardScriptLoader.init("USX:English (US International)",1, 0, true, false);;var Identity = Identity || {}; (function(i) { i.wlImgSm ="https://storage.live.com/users/0x{0}/myprofile/expressionprofile/profilephoto:UserTileStatic/p?ck=1\u0026ex=720\u0026sid=2F2BBB12E4EE6C7D3F98ABD5E5466D5B\u0026fofoff=1"; i.wlImgLg ="https://storage.live.com/users/0x{0}/myprofile/expressionprofile/profilephoto:UserTileMedium/p?ck=1\u0026ex=720\u0026sid=2F2BBB12E4EE6C7D3F98ABD5E5466D5B\u0026fofoff=1";i.popupLoginUrls = {"WindowsLiveId":"https://login.live.com/login.srf?wa=wsignin1.0\u0026rpsnv=11\u0026ct=1633463083\u0026rver=6.0.5286.0\u0026wp=MBI_SSL\u0026wreply=https:%2F%2fwww.bing.com%2Fsecure%2FPassport.aspx%3Fpopup%3D1\u0026lc=1033\u0026id=264960"}; })(Identity);;var WireUp,WireConnector,SignalConnector;(function(n){function f(n){var u=[],f,t,i,r,e;if(!n)return u;for(f=n.split(","),t=0;t<f.length;++t)(i=f[t],i&&0!==i.length)&&(r=i.split("/"),e={ci:r[0],cp:r[1],ct:r[2]},u.push(e));return u}function e(n){var t ...
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# var sj_appHTML=function(n,t){var f,e,o,r,i,s,h;if(t&&n){var c="innerHTML",l="script",a="appendChild",v="length",y="src",p=sj_ce,u=p("div");if(u[c]="<br>"+t,f=u.childNodes,u.removeChild(f[0]),e=u.getElementsByTagName(l),e)for(o=0;o<e[v];o++)r=p(l),i=e[o],i&&(r.type=i.type=="module"||i.type=="importmap"?i.type:"text/javascript",s=i.getAttribute(y),s?(r.setAttribute(y,s),r.setAttribute("crossorigin","anonymous")):(r.text=i[c],r.setAttribute("data-bing-script","1")),i.parentNode.replaceChild(r,i));for(h=_d.createDocumentFragment();f[v];)h[a](f[0]);n[a](h)}};
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# 0;
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# var wlc=function(n,t,i){var u,f,r;n&&Identity&&(u=Identity.popupLoginUrls)&&(f=u.WindowsLiveId)&&Identity.wlProfile&&(r=_d.createElement("iframe"),r.style.display="none",r.src=f+"&checkda=1",r.setAttribute("data-priority","2"),_d.body.appendChild(r),i&&t&&t("SRCHHPGUSR","WTS",i,1,"/"))};
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# (function() { var config ={"url":"https%3a%2f%2flogin.microsoftonline.com%2fcommon%2foauth2%2fauthorize%3fclient_id%3d9ea1ad79-fdb6-4f9a-8bc3-2b70f96e34c7%26response_type%3did_token%26nonce%3d57f10d0e-73b2-4e14-8a3a-bddc6cf2d76e%26redirect_uri%3dhttps%253a%252f%252fwww.bing.com%252forgid%252fidtoken%252fnosignin%26scope%3dopenid%26response_mode%3dform_post%26msafed%3d0%26prompt%3dnone%26state%3d%257b%2522ig%2522%253a%2522F41D0DFAD9DF4FC69C6395E7C4088FE9%2522%257d","sandbox":"allow-forms allow-pointer-lock allow-popups allow-same-origin allow-scripts","currentEpoch":"1633463082000"}; if (false) { if (typeof dbg !== "undefined") { dbg.trace("OrgId", "Delaying SSO on postRBComplete event"); } sj_evt.bind('postRBComplete', function() { setTimeout(function() {_w.rms.js({'rms:answers:OrgId:SsoFrame':'\/rp\/Xp-HPHGHOZznHBwdn7OWdva404Y.gz.js',d:1});sj_evt.fire('ssoFrameExists', config); }, 500); }, true, null, true); } else { sj_evt.fire('ssoFrameExists', config); } })();;
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# sb_ie&&function(){function h(){if(t){var u=n.replace(/www\./i,"");return f&&i(t,r,n+"?PC="+f)||i(t,r,n)||i(t,r,u)||i(t,r,n+"?Form=HPPDH1")||i(t,r,n+"?PC=BNHP")||i(t,r,n+"?PC=BNSR")}return 0}function c(){return i(_w.external,s,n)!=0}function l(){if(u){var n=2*e+o;if(u==n)return!0}return!1}function a(){var n=_ge("hps");return n||(n=sj_ce("span","hps"),n.style.behavior="url(#default#homepage)",sj_b.appendChild(n)),n}function i(n,t,i){try{return n[t](i)}catch(r){return 0}}var s="IsSearchProviderInstalled",r="isHomepage",n="http://"+_d.domain+"/",u=sj_cook.get("_UR","D"),f=sj_cook.get("SRCHS","PC"),t=a(),e=h(),o=c();l()||(u=2*e+o,sj_cook.set("_UR","D",u,1,"/"))}();
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# (function(){function d(n,t){for(var r=[],i=0;i<t.length;i++)r.push({MonitorID:t[i].name,RequestID:t[i].guid,Result:Math.round(n[i])});return JSON.stringify(r)}function u(){function n(){return Math.floor((1+Math.random())*65536).toString(16).substring(1)}return n()+n()+n()+n()+n()+n()+n()+n()}function h(){return window.performance&&window.performance.getEntriesByName?!0:!1}function c(n,t,i,r,u,f){function l(i){var w,b,p,k,y,g,nt;if(e!=null&&sb_ct(e),s[i]=c!=null?(new Date).getTime()-c:-1,i=(a+v)%n.length,o=new Image,a++<n.length)c=(new Date).getTime(),o.onload=function(){l(i)},w=function(){o.onload=null;o.onerror=null;c=null;l(i)},e=sb_st(function(){w()},t),o.onerror=function(){e!=null&&sb_ct(e);e=null;w()},o.src=n[i];else{if(r!=null&&r.length!==0){if(h())for(y=0;y<n.length;y++)b=n[y],p=window.performance.getEntriesByName(b),s[y]!=-1&&p&&p[0]&&(s[y]=p[0].duration);for(k=d(s,u),y=0;y<r.length;y++)g=r[y],nt=new Image,nt.src=g+k}f!=null&&f()}}var c,e,s=[],v=Math.floor(Math.random()*n.length),a=0,o;sb_st(function(){l(0)},i)}var t=window.location.protocol+"//";if(this.JSON&&t!=="https://"){var n=[u(),u(),u()],f=t+n[0]+".clo.footprintdns.com/apc/",e=t+n[1]+".clo.footprintdns.com/apc/",o=t+n[2]+".clo.footprintdns.com/apc/",i="trans.gif",r=i,s=2e3,l=h(),a=_G.IG,v="&MonitorID=AZR&rid="+a+"&w3c="+l+"&prot="+window.location.protocol+"&v=4&DATA=",y=[t+"fp.msedge.net/r.gif?"+v],p=[f+i,e+i,o+i],w=[f+r+"?"+n[0],e+r+"?"+n[1],o+r+"?"+n[2]],b=[{name:"CLO",guid:n[0]},{name:"CLO",guid:n[1]},{name:"CLO",guid:n[2]}],k=function(){c(w,s,0,y,b,null)};c(p,s,1e3,null,null,k)}})();
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# 0;var sj_ajax=function(n,t){function c(){i[u]=h;i.abort&&i.abort()}function s(n,t){typeof n=="function"&&n(t,{request:i,appendTo:function(n){i&&sj_appHTML(n,i.responseText)}})}var r,i=sj_gx(),u="onreadystatechange",f,e=null,o,l=sb_st,a=sb_ct,h=function(){};if(!n||!i){s(r,!1);return}i.open("get",n,!0);t&&(r=t.callback,f=t.timeout,o=t.headers,Object.keys(o||{}).forEach(function(n){i.setRequestHeader(n,o[n])}));i[u]=function(){if(i.readyState===4){var n=!1;e!==null&&a(e);i.status===200&&(n=!0,i[u]=h);s(r,n)}};sj_evt.bind("ajax.unload",c);i.send();f>0&&(e=l(function(){c();s(r,!1)},f))};Feedback.Bootstrap.InitializeFeedback({page:true},"sb_feedback",1,0,0);;
# //]]>--></div><div style="display:none"><!--//<![CDATA[
# sj_evt.bind("promptForUserLocationInit", function() { PromptForUserLocation.init("LAT={0}|LON={1}|A={2}|N={3}|C={4}|S={5}|TS={6}|ETS={7}|","DLOC","BLOCK","ULOC",600,"/Geolocation/getLocName?lat={0}\u0026lon={1}",true); }, 1);;
# //]]>--></div></div><script type="text/javascript">//<![CDATA[
# _G.HT=new Date;
# //]]></script></body></html>

# %%
r.find('a', href = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-998ac7ed2c38> in <module>
# ----> 1 r.find('a', href = True)
#
# AttributeError: 'Response' object has no attribute 'find'
